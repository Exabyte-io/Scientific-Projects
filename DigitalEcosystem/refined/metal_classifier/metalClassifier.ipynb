# %% [markdown]
# # Metal Classifier
#
# In this notebook, we train an XGBoost classifier to predict whether a system is metallic or not (bandgap <0.1 eV), and use this as an automated means of cleaning our dataset.
#
# At the end, we assess model performance, and observe that our data is largely Tweedie-distributed once we remove the metallic systems.

# %%
import copy
import sys

import pandas as pd
import numpy as np
import optuna
import xgboost
import imblearn.over_sampling
import sklearn.model_selection
import dscribe.descriptors
import tqdm
import sklearn.pipeline

import functools

import matplotlib.pyplot as plt
import sklearn.impute
import seaborn as sns

sys.path.append("../../../")
import DigitalEcosystem.utils.figures

tqdm.tqdm.pandas()

# %%
# Random seeds for reproducibility
RANDOM_SEED = 1234
import random
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # Read in the Dataset

# %%
# Load up the data
data_path = "../httpot/full_featurized_data.pkl"
data = pd.read_pickle(data_path)

cols_to_drop = ['formula',
                'discovery_process (unitless)',
                'potcars (unitless)',
                'is_hubbard (unitless)',
                'energy_per_atom (eV)',
                'exfoliation_energy_per_atom (eV/atom)',
                'is_bandgap_direct (unitless)',
                'is_metal (unitless)',
                'energy_vdw_per_atom (eV/atom)',
                'total_magnetization (Bohr Magneton)']
target_column = ['bandgap (eV)']
matpedia_id = ['2dm_id (unitless)']
atoms_col = ['atoms_object (unitless)']

# %% [markdown]
# # Featurization
#
# Here, we use the Sine Matrix eigenspectrum (DScribe Documentation here: [Link](https://singroup.github.io/dscribe/0.3.x/tutorials/sine_matrix.html)) as our input feature to determine metallicity. We'd also tried the Ewald Summation Matrix eigenspectrum (DScribe Documentation here: [Link](https://singroup.github.io/dscribe/latest/tutorials/descriptors/ewald_sum_matrix.html)), but found that the Sine Matrix led to better performnance.

# %%
# Generate the Sine Matrix Fingerprint
max_atoms = max(data['atoms_object (unitless)'].apply(len))
sine_eigenspectrum = dscribe.descriptors.SineMatrix(n_atoms_max=max_atoms,
                                                         permutation='eigenspectrum',
                                                         sparse=False)
data['sine_matrix'] = data['atoms_object (unitless)'].progress_apply(lambda atoms: np.real(sine_eigenspectrum.create(atoms)))
# Out:
# 100%|██████████| 6351/6351 [00:12<00:00, 516.92it/s]

# %% [markdown]
# Next, we'll label our data. We'll say that it's a metal if its DFT bandgap is less than 0.1 eV.

# %%
# Manually label metals/nonmetals
bandgap_cutoff = 0.1

data['metal'] = data['bandgap (eV)'] < bandgap_cutoff
train, test = sklearn.model_selection.train_test_split(data, test_size=0.1, stratify=data['metal'], random_state=RANDOM_SEED)

# %% [markdown]
# # Train/Test Split
# Then, we'll split up our data into a training and testing set. We'll stratify our dataset to ensure the same proportion of metals are found in both the training and test set.

# %%
# Pull out the X and Y values
def get_x_y(df):
    x = np.vstack(df['sine_matrix'])
    y = df['metal'].apply(int).to_numpy()
    return x,y
train_x, train_y = get_x_y(train)
test_x, test_y = get_x_y(test)

# %% [markdown]
# # K-Means SMOTE
# At this point, our dataset is slightly imbalanced. To address this, we'll use the K-means variation of SMOTE (Imbalanced-Learn Documentation here: [Link](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.KMeansSMOTE.html)). This is a variation on SMOTE that first performs the K-Means algorithm to generate class labels within the minority class, and then upsamples those. It's shown very promising performance for imbalanced classification problems compared to the original SMOTE algorithm (Original publication hosted at https://arxiv.org/abs/1711.00837).
#
# To avoid contaminating our test set with information about the training set, we perform K-means SMOTE *after* the train/test split.

# %%
# Upsample the training set with SMOTE
knn_smote = imblearn.over_sampling.KMeansSMOTE(
    random_state=RANDOM_SEED,
    k_neighbors = 4
)
res_x, res_y = knn_smote.fit_resample(train_x, train_y)

# %% [markdown]
# # Hyperparameter Optimization
#
# For this work, we'll use an XGBoost classifier. Several of its most important hyperparameters are tuned via Optuna, a Bayesian optimization framework implented in Python.
#
# In addition to optimizing the hyperparameters, we'll also investigate the use of a scaler. Optuna can choose from the following options:
# 1. No scaler being applied
# 2. A Min/Max scaler
# 3. A StandardScaler

# %%
current_pipeline = None
best_pipeline = None

def keep_best_bandgap_model(study, trial):
    """
    Records the best bandgap model found so far
    """
    global best_pipeline
    try:
        if study.best_trial == trial:
            best_pipeline = current_pipeline
    except ValueError:
        pass

def objective(trial: optuna.Trial):
    global current_pipeline

    tr_x, val_x, tr_y, val_y = sklearn.model_selection.train_test_split(res_x, res_y, test_size=0.2, random_state=RANDOM_SEED)

    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0, 1),
        'min_split_loss': trial.suggest_float('min_split_loss', 0, 1),
        'max_depth': trial.suggest_int('max_depth', 1, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 2),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 2)
    }

    scalers = {
        "StandardScaler": sklearn.preprocessing.StandardScaler(),
        "MinMaxScaler": sklearn.preprocessing.MinMaxScaler()
    }

    scaler = trial.suggest_categorical('scaler', scalers.keys())

    current_pipeline = sklearn.pipeline.Pipeline([
        (scaler, scalers[scaler]),
        ("XGB_Classifier", xgboost.sklearn.XGBClassifier(**params,
                                               n_estimators=100,
                                               objective='binary:logistic',
                                               use_label_encoder=False,
                                               random_state=RANDOM_SEED),)
    ])

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, 'validation_0-auc')

    current_pipeline.fit(X=tr_x, y=tr_y,
                         **{
                            'XGB_Classifier__eval_set': [[val_x, val_y]],
                            'XGB_Classifier__eval_metric': 'auc',
                            'XGB_Classifier__early_stopping_rounds': 5,
                            'XGB_Classifier__callbacks': [pruning_callback],
                            'XGB_Classifier__verbose': False
                         })

    preds = current_pipeline.predict(val_x)
    pred_labels = np.rint(preds)
    f1 = sklearn.metrics.f1_score(val_y, pred_labels)

    return f1

# %% [markdown]
# We'll run Optuna using its TPE Sampler (the default; documentation here: [Link](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.samplers.TPESampler.html)) with a random seed supplied. Additionally, we'll use the HyperBand pruner to prune trials that are not promising (Documentation link here: [Link](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.pruners.HyperbandPruner.html)).
#
# We choose the HyperBand pruner because it's demonstrated accelerate convergence faster than many of the other pruning techniques available in Optuna: [Blogpost Link](https://tech.preferred.jp/en/blog/how-we-implement-hyperband-in-optuna/)

# %%
study = optuna.create_study(
    sampler = optuna.samplers.TPESampler(
        seed=RANDOM_SEED,
        warn_independent_sampling=True,
        consider_endpoints=True,
    ),
    pruner = optuna.pruners.HyperbandPruner(
        min_resource=1,
        max_resource=100),
    direction='maximize',
)
# Out:
# [I 2021-08-18 16:34:16,706] A new study created in memory with name: no-name-2318fccc-11dc-4e24-93a1-59ae324df35a

# %%
study.optimize(objective, n_trials=1000, callbacks=[keep_best_bandgap_model])
# Out:
# [I 2021-08-18 16:34:16,903] Trial 0 finished with value: 0.7523727351164796 and parameters: {'learning_rate': 0.1915194503788923, 'min_split_loss': 0.6221087710398319, 'max_depth': 44, 'min_child_weight': 7.853585837137692, 'reg_lambda': 1.559951616237607, 'reg_alpha': 0.5451852105652832, 'scaler': 'MinMaxScaler'}. Best is trial 0 with value: 0.7523727351164796.
# [I 2021-08-18 16:34:17,076] Trial 1 finished with value: 0.7595993322203672 and parameters: {'learning_rate': 0.9581393536837052, 'min_split_loss': 0.8759326347420947, 'max_depth': 36, 'min_child_weight': 5.009951255234587, 'reg_lambda': 1.3669258703442726, 'reg_alpha': 1.4254040539658004, 'scaler': 'MinMaxScaler'}. Best is trial 1 with value: 0.7595993322203672.
# [I 2021-08-18 16:34:17,249] Trial 2 finished with value: 0.7724252491694352 and parameters: {'learning_rate': 0.5030831653078097, 'min_split_loss': 0.013768449590682241, 'max_depth': 78, 'min_child_weight': 8.826411906361166, 'reg_lambda': 0.7297719678027446, 'reg_alpha': 1.2307923568669874, 'scaler': 'MinMaxScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:17,327] Trial 3 finished with value: 0.7232968881412951 and parameters: {'learning_rate': 0.9331401019825216, 'min_split_loss': 0.6513781432265774, 'max_depth': 40, 'min_child_weight': 7.887301429407455, 'reg_lambda': 0.6336722443377425, 'reg_alpha': 1.1361973052521384, 'scaler': 'StandardScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:17,371] Trial 4 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:17,393] Trial 5 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:17,536] Trial 6 finished with value: 0.7514843087362172 and parameters: {'learning_rate': 0.329668445620915, 'min_split_loss': 0.5029668331126184, 'max_depth': 12, 'min_child_weight': 6.071937062184846, 'reg_lambda': 1.1318892861010628, 'reg_alpha': 0.01352812398000558, 'scaler': 'MinMaxScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:17,574] Trial 7 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:17,616] Trial 8 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:17,643] Trial 9 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:17,809] Trial 10 finished with value: 0.7639123102866778 and parameters: {'learning_rate': 0.4368931721756102, 'min_split_loss': 0.6121489970657575, 'max_depth': 92, 'min_child_weight': 6.2573666996253525, 'reg_lambda': 1.4119951301635465, 'reg_alpha': 0.29966743197985446, 'scaler': 'MinMaxScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:17,834] Trial 11 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:17,859] Trial 12 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:17,879] Trial 13 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:17,976] Trial 14 finished with value: 0.6986531986531986 and parameters: {'learning_rate': 0.45781164889742754, 'min_split_loss': 0.9204025710930878, 'max_depth': 88, 'min_child_weight': 2.526157550465302, 'reg_lambda': 0.6960175857386923, 'reg_alpha': 0.3651774631606175, 'scaler': 'StandardScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:18,132] Trial 15 finished with value: 0.7529411764705883 and parameters: {'learning_rate': 0.7266584615621408, 'min_split_loss': 0.9000878368097077, 'max_depth': 78, 'min_child_weight': 5.991547806042924, 'reg_lambda': 0.5822504897957497, 'reg_alpha': 0.30279052881486423, 'scaler': 'MinMaxScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:18,160] Trial 16 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,204] Trial 17 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:18,254] Trial 18 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:18,285] Trial 19 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,342] Trial 20 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,465] Trial 21 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:34:18,517] Trial 22 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,591] Trial 23 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:34:18,664] Trial 24 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:18,713] Trial 25 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,766] Trial 26 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,819] Trial 27 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:18,934] Trial 28 finished with value: 0.7554076539101497 and parameters: {'learning_rate': 0.8905571879288573, 'min_split_loss': 0.9732647911186689, 'max_depth': 60, 'min_child_weight': 3.6607449772047085, 'reg_lambda': 0.646189385932499, 'reg_alpha': 1.742846510097396, 'scaler': 'MinMaxScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:19,013] Trial 29 finished with value: 0.6952141057934509 and parameters: {'learning_rate': 0.3656190873671856, 'min_split_loss': 0.8016025985027602, 'max_depth': 79, 'min_child_weight': 7.01355379236693, 'reg_lambda': 1.2455531732063982, 'reg_alpha': 0.9873652914942241, 'scaler': 'StandardScaler'}. Best is trial 2 with value: 0.7724252491694352.
# [I 2021-08-18 16:34:19,098] Trial 30 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:19,150] Trial 31 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:19,203] Trial 32 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:19,258] Trial 33 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:19,310] Trial 34 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:19,672] Trial 35 finished with value: 0.7734241908006816 and parameters: {'learning_rate': 0.41171308151329356, 'min_split_loss': 0.6198489077545609, 'max_depth': 47, 'min_child_weight': 0.04732317901602573, 'reg_lambda': 0.4256813226162201, 'reg_alpha': 1.2205079541721826, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:19,765] Trial 36 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:34:19,864] Trial 37 finished with value: 0.7306711979609176 and parameters: {'learning_rate': 0.9790388199339376, 'min_split_loss': 0.881232246338927, 'max_depth': 63, 'min_child_weight': 9.304865334026656, 'reg_lambda': 1.4495799062048778, 'reg_alpha': 1.4333557721107124, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:19,948] Trial 38 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:20,141] Trial 39 finished with value: 0.7444633730834753 and parameters: {'learning_rate': 0.34334494452375763, 'min_split_loss': 0.9965516787398585, 'max_depth': 60, 'min_child_weight': 0.7706132294486867, 'reg_lambda': 0.47515328666804363, 'reg_alpha': 1.3672989960053465, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:20,207] Trial 40 finished with value: 0.6730937773882558 and parameters: {'learning_rate': 0.28206978311608777, 'min_split_loss': 0.3349959688919273, 'max_depth': 9, 'min_child_weight': 7.608491470573861, 'reg_lambda': 1.0185448943279078, 'reg_alpha': 1.3220948352169044, 'scaler': 'StandardScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:20,263] Trial 41 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:20,356] Trial 42 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:34:20,604] Trial 43 finished with value: 0.7560553633217993 and parameters: {'learning_rate': 0.15591702792464174, 'min_split_loss': 0.7960431979444791, 'max_depth': 60, 'min_child_weight': 0.9825612049943495, 'reg_lambda': 0.3586802422376099, 'reg_alpha': 1.135517130780007, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:20,807] Trial 44 finished with value: 0.7623089983022071 and parameters: {'learning_rate': 0.35174682158758874, 'min_split_loss': 0.6301331125022921, 'max_depth': 36, 'min_child_weight': 2.1281993764846496, 'reg_lambda': 0.44663844624530435, 'reg_alpha': 0.8391275834616554, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:20,857] Trial 45 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:20,916] Trial 46 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:20,974] Trial 47 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:21,057] Trial 48 finished with value: 0.7032418952618454 and parameters: {'learning_rate': 0.0021894308231216186, 'min_split_loss': 0.04196524456467021, 'max_depth': 15, 'min_child_weight': 5.982371851051667, 'reg_lambda': 0.2129210440237217, 'reg_alpha': 0.5943179723486358, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:21,113] Trial 49 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:21,290] Trial 50 finished with value: 0.7292539815590947 and parameters: {'learning_rate': 0.0226804761247833, 'min_split_loss': 0.8550546861316567, 'max_depth': 31, 'min_child_weight': 7.587834447539041, 'reg_lambda': 1.1265502202797322, 'reg_alpha': 0.07632836435729629, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:21,489] Trial 51 finished with value: 0.7502131287297529 and parameters: {'learning_rate': 0.22762113230106854, 'min_split_loss': 0.5616535891544917, 'max_depth': 61, 'min_child_weight': 0.828195129832153, 'reg_lambda': 0.9383146207758226, 'reg_alpha': 0.4577128917342318, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:21,558] Trial 52 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:21,637] Trial 53 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:21,951] Trial 54 finished with value: 0.7264957264957265 and parameters: {'learning_rate': 0.07614967183476123, 'min_split_loss': 0.5680608197704446, 'max_depth': 54, 'min_child_weight': 0.3528272128189802, 'reg_lambda': 1.103927302342309, 'reg_alpha': 0.46407260982218, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:22,112] Trial 55 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:34:22,351] Trial 56 finished with value: 0.7609254498714654 and parameters: {'learning_rate': 0.31174267322195126, 'min_split_loss': 0.6356786787002305, 'max_depth': 71, 'min_child_weight': 1.0384026352646625, 'reg_lambda': 0.8951206748873267, 'reg_alpha': 1.1045392714844307, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:22,423] Trial 57 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:22,714] Trial 58 finished with value: 0.7723440134907251 and parameters: {'learning_rate': 0.18326634939267783, 'min_split_loss': 0.7974113080911386, 'max_depth': 62, 'min_child_weight': 5.556533844497369, 'reg_lambda': 1.2589830892447686, 'reg_alpha': 1.372360150662204, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:22,796] Trial 59 finished with value: 0.7065767284991569 and parameters: {'learning_rate': 0.8564774570595708, 'min_split_loss': 0.7277960155986192, 'max_depth': 70, 'min_child_weight': 4.723509390701848, 'reg_lambda': 1.7137458838690016, 'reg_alpha': 1.3294866678086121, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:22,855] Trial 60 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:22,912] Trial 61 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:22,979] Trial 62 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:23,039] Trial 63 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:23,096] Trial 64 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:23,289] Trial 65 finished with value: 0.7465277777777778 and parameters: {'learning_rate': 0.24637403957734472, 'min_split_loss': 0.6051242227010319, 'max_depth': 65, 'min_child_weight': 1.2356800006681745, 'reg_lambda': 0.9121981478886793, 'reg_alpha': 0.8476126443847631, 'scaler': 'MinMaxScaler'}. Best is trial 35 with value: 0.7734241908006816.
# [I 2021-08-18 16:34:23,372] Trial 66 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:23,435] Trial 67 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:23,624] Trial 68 finished with value: 0.7745180217937971 and parameters: {'learning_rate': 0.39468858344517255, 'min_split_loss': 0.03104959835636134, 'max_depth': 58, 'min_child_weight': 8.502517453488608, 'reg_lambda': 1.9029777303472901, 'reg_alpha': 1.3659575942165334, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:23,701] Trial 69 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:23,754] Trial 70 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:23,899] Trial 71 finished with value: 0.7291487532244196 and parameters: {'learning_rate': 0.24376585865507794, 'min_split_loss': 0.5299409617440638, 'max_depth': 100, 'min_child_weight': 9.968075844398935, 'reg_lambda': 1.8989822409359678, 'reg_alpha': 1.9458875325324818, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:23,976] Trial 72 finished with value: 0.7037974683544305 and parameters: {'learning_rate': 0.9035913470702983, 'min_split_loss': 0.2776149982333721, 'max_depth': 26, 'min_child_weight': 6.997032628614107, 'reg_lambda': 1.8031377924978789, 'reg_alpha': 1.9673846502431562, 'scaler': 'StandardScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:24,077] Trial 73 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:24,141] Trial 74 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:24,198] Trial 75 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:24,330] Trial 76 finished with value: 0.7331081081081081 and parameters: {'learning_rate': 0.6066752162291601, 'min_split_loss': 0.8221597885758906, 'max_depth': 63, 'min_child_weight': 1.179230575007103, 'reg_lambda': 0.5717553467023127, 'reg_alpha': 1.9734944306757292, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:24
 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:48,031] Trial 261 finished with value: 0.7244367417677643 and parameters: {'learning_rate': 0.37419273235153866, 'min_split_loss': 0.07297582409104802, 'max_depth': 41, 'min_child_weight': 9.957682107601697, 'reg_lambda': 1.563422541416431, 'reg_alpha': 1.2559814676986778, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:48,109] Trial 262 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:48,274] Trial 263 finished with value: 0.7440273037542662 and parameters: {'learning_rate': 0.5129644482953379, 'min_split_loss': 0.8653500618488505, 'max_depth': 93, 'min_child_weight': 2.7309540298829402, 'reg_lambda': 0.6109863965557847, 'reg_alpha': 0.727976901057112, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:48,560] Trial 264 finished with value: 0.7653061224489796 and parameters: {'learning_rate': 0.3348494528217723, 'min_split_loss': 0.5948155468931055, 'max_depth': 64, 'min_child_weight': 0.8686879889458246, 'reg_lambda': 0.8825433113915739, 'reg_alpha': 1.2099060006640847, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:48,660] Trial 265 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:48,741] Trial 266 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:48,819] Trial 267 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:48,890] Trial 268 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:48,975] Trial 269 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:49,063] Trial 270 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:49,144] Trial 271 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:49,248] Trial 272 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:49,336] Trial 273 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:49,432] Trial 274 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:49,588] Trial 275 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:34:49,696] Trial 276 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:34:49,863] Trial 277 finished with value: 0.7319587628865979 and parameters: {'learning_rate': 0.33348851252022116, 'min_split_loss': 0.16904734962797074, 'max_depth': 18, 'min_child_weight': 9.480337780034615, 'reg_lambda': 1.6638182892089763, 'reg_alpha': 1.5821651138434218, 'scaler': 'MinMaxScaler'}. Best is trial 68 with value: 0.7745180217937971.
# [I 2021-08-18 16:34:49,944] Trial 278 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:34:50,034] Trial 279 pruned. Trial was pruned at iteration 1.
# ...
# [I 2021-08-18 16:36:32,423] Trial 901 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:32,740] Trial 902 finished with value: 0.7728415758591787 and parameters: {'learning_rate': 0.3301049460212404, 'min_split_loss': 0.7096271359515449, 'max_depth': 39, 'min_child_weight': 5.865536974523282, 'reg_lambda': 0.06169428092718199, 'reg_alpha': 1.437533049471312, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:33,094] Trial 903 finished with value: 0.7579831932773109 and parameters: {'learning_rate': 0.3384722438731987, 'min_split_loss': 0.7064341339168179, 'max_depth': 38, 'min_child_weight': 6.828542399594398, 'reg_lambda': 0.9177327736866928, 'reg_alpha': 1.4289103205842744, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:33,299] Trial 904 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:33,547] Trial 905 finished with value: 0.7467811158798284 and parameters: {'learning_rate': 0.3062247480338141, 'min_split_loss': 0.2896754930795866, 'max_depth': 54, 'min_child_weight': 6.7972651750005815, 'reg_lambda': 0.8938199389025037, 'reg_alpha': 1.3597678323155329, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:33,682] Trial 906 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:33,948] Trial 907 finished with value: 0.7408041060735672 and parameters: {'learning_rate': 0.23586887274688817, 'min_split_loss': 0.496341360305232, 'max_depth': 75, 'min_child_weight': 0.9694827264039483, 'reg_lambda': 0.7338152265790727, 'reg_alpha': 0.8103827593907511, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:34,079] Trial 908 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:34,249] Trial 909 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36:34,405] Trial 910 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:34,539] Trial 911 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:34,669] Trial 912 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:34,802] Trial 913 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:34,978] Trial 914 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36
 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:42,236] Trial 956 finished with value: 0.7108013937282229 and parameters: {'learning_rate': 0.56520448973509, 'min_split_loss': 0.45337910276883403, 'max_depth': 83, 'min_child_weight': 3.7118487408545073, 'reg_lambda': 0.24446849026213002, 'reg_alpha': 1.7724330846379606, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:42,505] Trial 957 finished with value: 0.7460595446584938 and parameters: {'learning_rate': 0.20619982872554504, 'min_split_loss': 0.5842885285491994, 'max_depth': 60, 'min_child_weight': 0.9718007089456263, 'reg_lambda': 1.247391108466378, 'reg_alpha': 0.8784605333469888, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:42,837] Trial 958 finished with value: 0.75 and parameters: {'learning_rate': 0.12309844668509473, 'min_split_loss': 0.36047384092395823, 'max_depth': 34, 'min_child_weight': 6.2008870120269695, 'reg_lambda': 1.2109318293154405, 'reg_alpha': 0.7357383850185226, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:43,016] Trial 959 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36:43,151] Trial 960 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:43,356] Trial 961 finished with value: 0.7427597955706985 and parameters: {'learning_rate': 0.2565348727516807, 'min_split_loss': 0.23433320843896172, 'max_depth': 12, 'min_child_weight': 7.778654442766144, 'reg_lambda': 0.4904527537350509, 'reg_alpha': 1.0128820428333078, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:43,588] Trial 962 finished with value: 0.7550675675675677 and parameters: {'learning_rate': 0.3647786566487558, 'min_split_loss': 0.717147168749991, 'max_depth': 29, 'min_child_weight': 7.055393135597471, 'reg_lambda': 0.1971398400697505, 'reg_alpha': 0.3472102777919911, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:43,754] Trial 963 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:44,120] Trial 964 finished with value: 0.7654109589041097 and parameters: {'learning_rate': 0.2689638874121063, 'min_split_loss': 0.5904156228249264, 'max_depth': 86, 'min_child_weight': 0.7711493415354083, 'reg_lambda': 1.08183272145531, 'reg_alpha': 0.7520377505830088, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:44,336] Trial 965 finished with value: 0.7363945578231292 and parameters: {'learning_rate': 0.3837224131597725, 'min_split_loss': 0.6768687061339098, 'max_depth': 43, 'min_child_weight': 6.651145302670043, 'reg_lambda': 0.008907348830296827, 'reg_alpha': 1.1342585153563363, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:44,596] Trial 966 finished with value: 0.768581081081081 and parameters: {'learning_rate': 0.4935680278737911, 'min_split_loss': 0.5503328203028572, 'max_depth': 85, 'min_child_weight': 2.9558377237866744, 'reg_lambda': 0.2501673143304166, 'reg_alpha': 1.8997906139563878, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:44,734] Trial 967 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:44,905] Trial 968 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36:45,043] Trial 969 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:45,228] Trial 970 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36:45,388] Trial 971 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:45,523] Trial 972 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:45,653] Trial 973 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:45,839] Trial 974 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36:45,999] Trial 975 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:46,209] Trial 976 finished with value: 0.7726894254787676 and parameters: {'learning_rate': 0.5664167432039929, 'min_split_loss': 0.36063649126533626, 'max_depth': 78, 'min_child_weight': 4.031975708096558, 'reg_lambda': 0.627526263949236, 'reg_alpha': 1.9603330333113056, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:46,395] Trial 977 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:46,648] Trial 978 finished with value: 0.7521367521367521 and parameters: {'learning_rate': 0.19941170775462214, 'min_split_loss': 0.13396744680949607, 'max_depth': 29, 'min_child_weight': 4.2116350757308885, 'reg_lambda': 0.1613106358868286, 'reg_alpha': 1.5699377843681608, 'scaler': 'StandardScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:46,787] Trial 979 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:47,163] Trial 980 finished with value: 0.7708154506437769 and parameters: {'learning_rate': 0.2852524498226039, 'min_split_loss': 0.5358713369402569, 'max_depth': 81, 'min_child_weight': 1.1303499889795254, 'reg_lambda': 1.1861711681654634, 'reg_alpha': 0.7746481897832967, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:47,389] Trial 981 finished with value: 0.7665271966527196 and parameters: {'learning_rate': 0.7250555446290659, 'min_split_loss': 0.28008121417695314, 'max_depth': 96, 'min_child_weight': 2.4706296770104608, 'reg_lambda': 0.46441548044330505, 'reg_alpha': 1.9906583364905717, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:47,518] Trial 982 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:47,655] Trial 983 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:47,826] Trial 984 finished with value: 0.7208121827411168 and parameters: {'learning_rate': 0.35447847123590154, 'min_split_loss': 0.7114057997686518, 'max_depth': 77, 'min_child_weight': 7.04102067082915, 'reg_lambda': 0.14193262155697686, 'reg_alpha': 0.35371169925454565, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:47,985] Trial 985 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:48,120] Trial 986 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:48,258] Trial 987 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:48,396] Trial 988 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:48,869] Trial 989 finished with value: 0.771043771043771 and parameters: {'learning_rate': 0.4131688580924371, 'min_split_loss': 0.48453648226140844, 'max_depth': 88, 'min_child_weight': 2.9212013776781296, 'reg_lambda': 0.19286196578679707, 'reg_alpha': 1.7897763970163036, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:49,034] Trial 990 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:49,279] Trial 991 finished with value: 0.7631133671742809 and parameters: {'learning_rate': 0.475715257602291, 'min_split_loss': 0.6392674017207568, 'max_depth': 74, 'min_child_weight': 1.8190248410074223, 'reg_lambda': 0.5450977864664267, 'reg_alpha': 1.9972646810974521, 'scaler': 'MinMaxScaler'}. Best is trial 828 with value: 0.7864406779661017.
# [I 2021-08-18 16:36:49,414] Trial 992 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:49,580] Trial 993 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:49,716] Trial 994 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:49,900] Trial 995 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:36:50,041] Trial 996 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:50,188] Trial 997 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:36:50,322] Trial 998 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:36:50,465] Trial 999 pruned. Trial was pruned at iteration 1.

# %% [markdown]
# # ROC Curves
#
# To assess model performance, we'll print out some ROC curves here.
#
# Although we hold out a validation set in our objective function, we do not retrain the model on the entire training set, as this validation set was also used to control the early stopping of our XGBoost model (and thus helps guard against overfitting).
#
# Overall, we see generally good results for both our training set and our testing set.

# %%
plot_roc = functools.partial(DigitalEcosystem.utils.figures.plot_roc, classifier=best_pipeline)

plot_roc(train_x, train_y, "Training")
plot_roc(test_x, test_y, "Test")

# %% [markdown]
# # Confusion Matrices
#
# For a more fine-grained picture of our model's performance, we also draw confusion matrices here.
#
# Overall, our classification is slightly biased towards under-prediction of the number of metals in the dataset when the model's probability cutoff is set to 0.5. Although we did not tune this cutoff, the process would be easy: we could simply lower the probability at-which something is considered to be a metal until the number of misclassified metals and nonmetals were equal in the training set.
#
# A few metrics of the model's performance, derived from the above ROC curves and the below confusion matrices, are summarized in the below table.
#
# | Metric   | Training Set | Test Set |
# |----------|--------------|----------|
# | TPR      | 0.893        | 0.738    |
# | FPR      | 0.074        | 0.167    |
# | Accuracy | 0.910        | 0.788    |
# | F1 Score | 0.904        | 0.767    |
# | ROC AUC  | 0.963        | 0.866    |
#
# Overall, we see good performnace in both our training and testing set, with similar error rates in both - which is a good indication that our model generalizes well to the testing set.

# %%
CUTOFF = 0.5


draw_confusion_matrix = functools.partial(DigitalEcosystem.utils.figures.draw_confusion_matrix,
                                          classifier=best_pipeline,
                                          cutoff=CUTOFF)

draw_confusion_matrix(train_x, train_y, "Training")
draw_confusion_matrix(test_x, test_y, "Test")

# %% [markdown]
# # Nonmetal Bandgap Regression
#
# Next, we'll move to the next step of our pipeline: predicting the bandgap of nonmetals.
#
# We'll use our trained classifier to label the dataset as "metal" or "nonmetal."

# %%
train['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(train_x)[:,1] > CUTOFF)
test['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(test_x)[:,1] > CUTOFF)
# Out:
# <ipython-input-13-b6931208e582>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(train_x)[:,1] > CUTOFF)
# <ipython-input-13-b6931208e582>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(test_x)[:,1] > CUTOFF)

# %% [markdown]
# Next, we'll separate out the predicted nonmetals from our training and testing set.

# %%
train_metals = train[train['pred_metal'] == True]
train_nonmetals = train[train['pred_metal'] != True]

test_metals = test[test['pred_metal'] == True]
test_nonmetals = test[test['pred_metal'] != True]

# %% [markdown]
# # Bandgap Distribution
#
# Before we perform the regression, let's also investigate the distribution of our data.
#
# ## Entire Dataset
#
# First, we look at the bandgap of all data in our dataset (including metals and nonmetals). We see a very large spike at approximately 0 bandgap, followed by a tail of wider bandgaps.

# %%
bins = np.arange(0,max(data['bandgap (eV)']), 0.5)
stat='density'

draw_train_test_histplot = functools.partial(DigitalEcosystem.utils.figures.save_train_test_histplot,
                                             column='bandgap (eV)',
                                             stat=stat,
                                             bins=bins)

draw_train_test_histplot(train, test,
                         "All Data",
                         "full_dataset_bandgap_histogram.jpeg")

# %% [markdown]
# ## Predicted-Nonmetals Only
#
# Next, we'll take a look at just rows from training and testing set which were labeled as nonmetals by our classifier.
#
# We see that our data distribution has changed - the training set and testing set seem to be a a mixture between a Poisson distribution and a Gamma distribution - this is the classic Tweedie distribution (Wikipedia article: [Link](https://en.wikipedia.org/wiki/Tweedie_distribution)).

# %%
draw_train_test_histplot(train_nonmetals,
                         test_nonmetals,
                         "Classififed as Nonmetals",
                         "normal_histplot.jpeg")

# %% [markdown]
# ## Predicted Metals Only
#
# Finally, we'll investigate our predicted metals and nonmetals. We see that, barring a few exceptions, materials that are predicted to be a metal at least tend to have a low bandgap.

# %%
draw_train_test_histplot(train_metals,
                         test_metals,
                         "Classified as Metals",
                         "metal_histplot.jpeg")

# %% [markdown]
# # Regression - Features
#
# Before we start doing any work with regression, we need to choose a set of features. Because we've been finding success in the past in this problem with the Xenonpy and Matminer-derived descriptors, we'll go ahead and extract those from our dataset.

# %%
xenonpy_descriptors = [col for col in data.columns if ":" in col]
matminer_descriptors = [
    'bond_length_average',
    'bond_angle_average',
    'average_cn',
    'global_instability',
    'perimeter_area_ratio',
    'ewald_energy_per_atom',
    'structural complexity per atom',
    'structural complexity per cell',
    'n_symmetry_ops'

]
xenonpy_matminer_descriptors = xenonpy_descriptors + matminer_descriptors#%%
target = ['bandgap (eV)']

# %% [markdown]
# Next, we'll separate out our X and Y columns, and we'll use Numpy to remove any NaN values that made their way into the dataset.
#
# This is an area of improvement, as we could have also imputed the NaN values instead.

# %%
train_x_reg = np.nan_to_num(train_nonmetals[xenonpy_matminer_descriptors].to_numpy())
train_y_reg = np.nan_to_num(train_nonmetals[target].to_numpy())

test_x_reg = np.nan_to_num(test_nonmetals[xenonpy_matminer_descriptors].to_numpy())
test_y_reg = np.nan_to_num(test_nonmetals[target].to_numpy())

# %% [markdown]
# # Tweedie Distribution - Investigation
#
# Finally, before we do our regression, let's revisit the Tweedie distribution we discussed earlier.
#
# The shape of the Tweedie distribution is controlled by a power parameter, which allows it to function as a generalization of a variety of other distributions, including the Poisson, Gamma, Normal, Gaussian, and other distributions. H2O has some very good documentation on this subject: [Link](https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/algo-params/tweedie_variance_power.html#:~:text=Tweedie%20distributions%20are%20a%20family,\)%3D%CF%95%CE%BCpi.).
#
# To estimate the power, we'll walk along powers ranging from 1.0 (Poisson) to almost 2.0 (Gamma), with intermediate powers representing a Tweedie distribution. At each step, we'll take 1,000 bootstrap samples of the dataset and calculate the mean tweedie deviance relative to the mean of the bandgap. We'll take the power that results in the lowest mean tweedie deviance as an estimate of the Tweedie power.
#
# Overall, we find the following results:
#
# | Data Subset     | Optimal Tweedie Power |
# |-----------------|-----------------------|
# | Full Dataset    | 1.0                   |
# | Train Nonmetals | 1.345                 |
# | Test Nonmetals  | 1.202                 |
#
# When we attempt to fit a model on our entire dataset, we see that the data is closest to a Poisson distribution.
#
# When we remove metals and testing set, however, we see that our data shifts to be more Tweedie - Distributed (a power between 1 and 2).Moreover, we see a slight difference in power between our training and testing set - which we can actually see in the above "Classified as Nonmetals" plot, particularly below 2 eV.
#
# This difference in distribution between our training set and testing set is likely to contribute to error in our regression model.

# %%
# Find the power that our data falls under in a tweedie distribution
def get_pow_plot(dist, filename):
    deviances = []
    n_boot_samples = 1000
    mesh_size = 100
    with tqdm.tqdm(total=mesh_size) as pbar:
        for tweedie_deviance_power in np.linspace(1,1.95,num=mesh_size):
            try:
                samples = []
                for i in range(n_boot_samples):
                    boot_sample = np.random.choice(dist, replace=True, size=len(dist))
                    samples.append(sklearn.metrics.mean_tweedie_deviance(y_true=boot_sample,
                                                                         y_pred=[abs(boot_sample.mean())]*len(boot_sample),
                                                                         power=tweedie_deviance_power))
                samp_mean = sum(samples) / len(samples)
                #samp_var = sum([sample - samp_mean for sample in samples])/ len(samples)
                deviances.append([tweedie_deviance_power, samp_mean])
            except ValueError:
                pass
            finally:
                pbar.update(1)

    plt.plot([i[0] for i in deviances],[i[1] for i in deviances], label="Bootstrapped Results")

    best_pow, best_dev = min(deviances, key=lambda i: i[1])
    plt.scatter([best_pow], [best_dev], marker="+", c='k', s=1000, lw=5, label="Minimum")

    plt.xlabel("Tweedie Distribution Power")
    plt.ylabel("Mean Tweedie Deviance")
    plt.title(f"{n_boot_samples} Bootstrap Samples")
    plt.legend()
    plt.savefig(filename)
    print(f"Best Pow is {best_pow} with Tweedie Deviance {best_dev}")
    plt.close()
    return best_pow


get_pow_plot(test_nonmetals['bandgap (eV)'].to_numpy(), "test_nonmetal_tweedie_power.jpeg")
get_pow_plot(data["bandgap (eV)"].to_numpy(), "full_dataset_tweedie_power.jpeg")
best_pow=get_pow_plot(train_nonmetals["bandgap (eV)"].to_numpy(), "train_nonmetal_tweedie_power.jpeg")
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.86it/s]
# Best Pow is 1.2015151515151514 with Tweedie Deviance 1.6242234755083755
# 100%|██████████| 100/100 [01:17<00:00,  1.29it/s]
# Best Pow is 1.0 with Tweedie Deviance 1.869589818335701
# 100%|██████████| 100/100 [00:47<00:00,  2.11it/s]
# Best Pow is 1.3454545454545455 with Tweedie Deviance 1.169751606551736

# %% [markdown]
# # Regression - XGBoost
#
# Finally, we'll train another XGBoost model, this time for regression of the bandgap. We'll again use Optuna to tune a few of the model's hyperparameter (fewer in the interest of time). We'll also just start with a Min/Max scaler, as some previous work we'd done on thi problem indicated good performance when this was used as a scaler versus standardization or not scaling.
#
# We'll finally draw a parity plot of our results.

# %%
current_reg = None
best_reg = None
def keep_best_reg(study, trial):
    global best_reg
    if study.best_trial == trial:
        best_reg = current_reg

tr_x_reg, val_x_reg, tr_y_reg, val_y_reg = sklearn.model_selection.train_test_split(np.nan_to_num(train_x_reg), train_y_reg, test_size=0.2, random_state=RANDOM_SEED)

def objective(trial: optuna.Trial):
    global current_reg


    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0, 1),
        'min_split_loss': trial.suggest_float('min_split_loss', 0, 2),
        'max_depth': trial.suggest_int('max_depth', 1, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0, 10),
    }

    current_reg = sklearn.pipeline.Pipeline([
        ("Scaler", sklearn.preprocessing.MinMaxScaler()),
        ("XGB_Regressor", xgboost.sklearn.XGBRegressor(**params,
                                               n_estimators=100,
                                               objective='reg:squarederror',
                                               random_state=RANDOM_SEED),)
    ])

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'validation_0-poisson-nloglik')
    current_reg.fit(X=tr_x_reg, y=tr_y_reg,
                         **{
                            'XGB_Regressor__eval_set': [[val_x_reg, val_y_reg]],
                            'XGB_Regressor__eval_metric': 'poisson-nloglik',
                            'XGB_Regressor__early_stopping_rounds': 50,
                            'XGB_Regressor__callbacks': [pruning_callback],
                            'XGB_Regressor__verbose': False
                         })

    score = sklearn.metrics.mean_poisson_deviance(
        y_true=val_y_reg,
        y_pred=abs(current_reg.predict(val_x_reg)),
    )

    return score

reg_study = optuna.create_study(
    sampler = optuna.samplers.TPESampler(
        seed = RANDOM_SEED,
        warn_independent_sampling = True,
        consider_endpoints = True
    ),
    pruner = optuna.pruners.HyperbandPruner(
        min_resource=1,
        max_resource=100),
    direction='minimize'
)

reg_study.optimize(func=objective, n_trials=500, callbacks=[keep_best_reg])
# Out:
# [I 2021-08-18 16:39:24,567] A new study created in memory with name: no-name-27a4057f-d9e6-4239-ba21-debe8cdec550
# [I 2021-08-18 16:39:27,138] Trial 0 finished with value: 0.5013859359918628 and parameters: {'learning_rate': 0.1915194503788923, 'min_split_loss': 1.2442175420796637, 'max_depth': 44, 'min_child_weight': 7.853585837137692}. Best is trial 0 with value: 0.5013859359918628.
# [I 2021-08-18 16:39:27,293] Trial 1 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:30,013] Trial 2 finished with value: 0.8349971483598068 and parameters: {'learning_rate': 0.9581393536837052, 'min_split_loss': 1.7518652694841894, 'max_depth': 36, 'min_child_weight': 5.009951255234587}. Best is trial 0 with value: 0.5013859359918628.
# [I 2021-08-18 16:39:30,090] Trial 3 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:33,608] Trial 4 finished with value: 0.6310554546258819 and parameters: {'learning_rate': 0.5030831653078097, 'min_split_loss': 0.027536899181364483, 'max_depth': 78, 'min_child_weight': 8.826411906361166}. Best is trial 0 with value: 0.5013859359918628.
# [I 2021-08-18 16:39:33,666] Trial 5 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:33,749] Trial 6 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:33,828] Trial 7 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:33,905] Trial 8 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:33,981] Trial 9 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:34,026] Trial 10 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:34,092] Trial 11 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:35,667] Trial 12 finished with value: 0.5034383164811117 and parameters: {'learning_rate': 0.329668445620915, 'min_split_loss': 1.0059336662252367, 'max_depth': 12, 'min_child_weight': 6.071937062184846}. Best is trial 0 with value: 0.5013859359918628.
# [I 2021-08-18 16:39:35,773] Trial 13 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:39,671] Trial 14 finished with value: 0.6421450692859162 and parameters: {'learning_rate': 0.5659446430505314, 'min_split_loss': 0.01352812398000558, 'max_depth': 62, 'min_child_weight': 9.121228864331544}. Best is trial 0 with value: 0.5013859359918628.
# [I 2021-08-18 16:39:39,829] Trial 15 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:44,090] Trial 16 finished with value: 0.4963257432418948 and parameters: {'learning_rate': 0.2852509600245098, 'min_split_loss': 1.249833410611822, 'max_depth': 48, 'min_child_weight': 1.9567517866589823}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:39:48,482] Trial 17 finished with value: 0.513494521591508 and parameters: {'learning_rate': 0.38231745203150647, 'min_split_loss': 0.10774737029247317, 'max_depth': 46, 'min_child_weight': 9.820047415219545}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:39:52,186] Trial 18 finished with value: 0.5031648831102291 and parameters: {'learning_rate': 0.12394270048696299, 'min_split_loss': 0.2387617958524968, 'max_depth': 74, 'min_child_weight': 5.873036334639846}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:39:52,331] Trial 19 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:52,437] Trial 20 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:52,595] Trial 21 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:52,707] Trial 22 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:39:53,111] Trial 23 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:39:53,262] Trial 24 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:53,369] Trial 25 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:53,477] Trial 26 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:53,902] Trial 27 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:39:55,402] Trial 28 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:39:56,494] Trial 29 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:39:56,980] Trial 30 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:39:57,165] Trial 31 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:39:57,346] Trial 32 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:57,566] Trial 33 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:57,672] Trial 34 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:39:57,787] Trial 35 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:39:57,966] Trial 36 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:39:59,575] Trial 37 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:39:59,727] Trial 38 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:40:00,258] Trial 39 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:40:01,747] Trial 40 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:40:01,909] Trial 41 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:40:05,135] Trial 42 finished with value: 0.8820456404866052 and parameters: {'learning_rate': 0.8538985671256417, 'min_split_loss': 0.574124850000018, 'max_depth': 18, 'min_child_weight': 1.3402120599884282}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:40:05,240] Trial 43 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:40:05,879] Trial 44 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:40:06,045] Trial 45 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:40:10,176] Trial 46 finished with value: 0.7563904830602988 and parameters: {'learning_rate': 0.00934857450024451, 'min_split_loss': 1.8012972423101838, 'max_depth': 98, 'min_child_weight': 5.568946791368349}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:40:10,289] Trial 47 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:40:10,536] Trial 48 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:40:10,665] Trial 49 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:40:10,807] Trial 50 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:40:11,066] Trial 51 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:40:11,183] Trial 52 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:40
pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:41:51,580] Trial 223 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:41:51,734] Trial 224 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:41:52,003] Trial 225 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:41:52,101] Trial 226 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:41:52,194] Trial 227 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:41:56,036] Trial 228 finished with value: 0.7115776582834418 and parameters: {'learning_rate': 0.6043340048360264, 'min_split_loss': 0.20620887771129448, 'max_depth': 81, 'min_child_weight': 9.455532358421245}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:42:00,262] Trial 229 finished with value: 0.538862315055303 and parameters: {'learning_rate': 0.25148692364966496, 'min_split_loss': 0.3604915996226521, 'max_depth': 80, 'min_child_weight': 4.780443893721783}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:42:02,463] Trial 230 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:42:06,453] Trial 231 pruned. Trial was pruned at iteration 81.
# [I 2021-08-18 16:42:06,686] Trial 232 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:06,835] Trial 233 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:06,930] Trial 234 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:07,027] Trial 235 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:07,235] Trial 236 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:07,465] Trial 237 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:07,535] Trial 238 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:07,703] Trial 239 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:07,847] Trial 240 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:08,089] Trial 241 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:08,389] Trial 242 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:09,883] Trial 243 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:42:11,527] Trial 244 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:42:12,063] Trial 245 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:42:12,289] Trial 246 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:14,373] Trial 247 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:42:15,753] Trial 248 finished with value: 0.5354932139301714 and parameters: {'learning_rate': 0.19705359754836405, 'min_split_loss': 1.228624284176385, 'max_depth': 6, 'min_child_weight': 2.9783929607332293}. Best is trial 16 with value: 0.4963257432418948.
# [I 2021-08-18 16:42:15,880] Trial 249 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:16,140] Trial 250 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:16,264] Trial 251 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:16,714] Trial 252 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:42:16,960] Trial 253 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:17,084] Trial 254 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:17,217] Trial 255 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:21,912] Trial 256 finished with value: 0.4872241425888491 and parameters: {'learning_rate': 0.14077570677818418, 'min_split_loss': 1.332967239801448, 'max_depth': 38, 'min_child_weight': 3.1780923622332464}. Best is trial 256 with value: 0.4872241425888491.
# [I 2021-08-18 16:42:26,966] Trial 257 finished with value: 0.4782642335622017 and parameters: {'learning_rate': 0.14920790773069326, 'min_split_loss': 0.7832621066977509, 'max_depth': 38, 'min_child_weight': 2.1951292854964097}. Best is trial 257 with value: 0.4782642335622017.
# [I 2021-08-18 16:42:35,056] Trial 258 finished with value: 0.4725781209315046 and parameters: {'learning_rate': 0.08088115139513105, 'min_split_loss': 0.8231517320265419, 'max_depth': 34, 'min_child_weight': 0.10628918819835231}. Best is trial 258 with value: 0.4725781209315046.
# [I 2021-08-18 16:42:35,174] Trial 259 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:35,273] Trial 260 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:35,350] Trial 261 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:35,530] Trial 262 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:35,694] Trial 263 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:42:39,990] Trial 264 finished with value: 0.5121806646495416 and parameters: {'learning_rate': 0.2270172011179237, 'min_split_loss': 0.3538440812091481, 'max_depth': 76, 'min_child_weight': 4.774598558694599}. Best is trial 258 with value: 0.4725781209315046.
# [I 2021-08-18 16:42:44,385] Trial 265 pruned. Trial was pruned at iteration 81.
# [I 2021-08-18 16:42:44,878] Trial 266 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:42:45,009] Trial 267 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:50,430] Trial 268 finished with value: 0.5114337021920563 and parameters: {'learning_rate': 0.1581265538591168, 'min_split_loss': 0.018099762009785303, 'max_depth': 73, 'min_child_weight': 4.951829309253111}. Best is trial 258 with value: 0.4725781209315046.
# [I 2021-08-18 16:42:50,676] Trial 269 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:51,102] Trial 270 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:42:51,307] Trial 271 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:51,431] Trial 272 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:51,564] Trial 273 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:42:51,699] Trial 274 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:51,816] Trial 275 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:52,305] Trial 276 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:42:52,503] Trial 277 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42:52,708] Trial 278 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:42
pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:24,988] Trial 455 finished with value: 0.509903685113792 and parameters: {'learning_rate': 0.2646915502462485, 'min_split_loss': 0.7073096264421254, 'max_depth': 50, 'min_child_weight': 3.9035342347280775}. Best is trial 378 with value: 0.4644050652307386.
# [I 2021-08-18 16:44:25,196] Trial 456 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:25,685] Trial 457 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:25,876] Trial 458 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:44:26,124] Trial 459 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:26,239] Trial 460 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:26,417] Trial 461 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:44:26,640] Trial 462 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:26,842] Trial 463 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:27,065] Trial 464 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:28,601] Trial 465 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:44:32,385] Trial 466 finished with value: 0.5074282018761128 and parameters: {'learning_rate': 0.15914266483411782, 'min_split_loss': 0.15774376197052867, 'max_depth': 20, 'min_child_weight': 6.952288317733189}. Best is trial 378 with value: 0.4644050652307386.
# [I 2021-08-18 16:44:32,586] Trial 467 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:32,679] Trial 468 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:33,179] Trial 469 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:34,016] Trial 470 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:44:34,156] Trial 471 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:35,485] Trial 472 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:44:35,594] Trial 473 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:35,696] Trial 474 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:35,786] Trial 475 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:35,896] Trial 476 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:35,973] Trial 477 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:36,060] Trial 478 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:36,236] Trial 479 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:36,315] Trial 480 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:36,556] Trial 481 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:36,677] Trial 482 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:37,062] Trial 483 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:37,419] Trial 484 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:37,508] Trial 485 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:38,010] Trial 486 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:38,110] Trial 487 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:38,286] Trial 488 pruned. Trial was pruned at iteration 27.
# [I 2021-08-18 16:44:38,405] Trial 489 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:42,141] Trial 490 finished with value: 0.5069145342353503 and parameters: {'learning_rate': 0.20570129999296005, 'min_split_loss': 0.3150036387940534, 'max_depth': 84, 'min_child_weight': 7.798425487892665}. Best is trial 378 with value: 0.4644050652307386.
# [I 2021-08-18 16:44:49,670] Trial 491 finished with value: 0.5201910313905521 and parameters: {'learning_rate': 0.24935543453955777, 'min_split_loss': 0.011846227048273428, 'max_depth': 29, 'min_child_weight': 4.616831701386701}. Best is trial 378 with value: 0.4644050652307386.
# [I 2021-08-18 16:44:49,864] Trial 492 pruned. Trial was pruned at iteration 3.
# [I 2021-08-18 16:44:50,253] Trial 493 pruned. Trial was pruned at iteration 9.
# [I 2021-08-18 16:44:50,386] Trial 494 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:50,461] Trial 495 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:50,565] Trial 496 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:50,704] Trial 497 pruned. Trial was pruned at iteration 1.
# [I 2021-08-18 16:44:53,726] Trial 498 finished with value: 0.5569079499058549 and parameters: {'learning_rate': 0.4751210354642072, 'min_split_loss': 1.121258164600593, 'max_depth': 93, 'min_child_weight': 8.330276673727921}. Best is trial 378 with value: 0.4644050652307386.
# [I 2021-08-18 16:44:53,862] Trial 499 pruned. Trial was pruned at iteration 1.

# %%
DigitalEcosystem.utils.figures.save_parity_plot(train_x_reg,
                                                test_x_reg,
                                                train_y_reg,
                                                test_y_reg,
                                                best_reg,
                                                "Bandgap (eV)",
                                                "parity.jpeg")
# Out:
# /Users/mat3ra/sisso_collab/.env/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# # Regression - Results
#
# Overall, we see okay performance of the model. Certainly not the big gains in performance that we had hoped for when removing the metals from the dataset.
#
# One thing we could try to improve our predictions here would be to manually remove all metals from the training set, then train on those. This would likely lead to even worse performance in the case of the metal systems that had been misclassified as nonmetals - but those are already wrong by quite a lot anyway.
#
# Below, we output the test-set error metrics, since those are the ones that really tell us if our model will generalize. Reproduced here:
#
# | Error Metric | Test-Set Value    |
# |--------------|-------------------|
# | MAE          | 0.631             |
# | RMSE         | 0.852             |
# | MAPE         | 646627325416641.8 |
# | R2           | 0.735             |
#
# - The MAE is comparable to a related model, MegNet [Link](https://github.com/materialsvirtuallab/megnet). MegNet is a graph convolution neural network trained on a variety of different datasets. When compared with DFT bandgaps from Materials Project (slightly different, as that dataset is of 3D materials and not 2D materials), they report a MAE of 0.33 eV for the bandgap. Considering we're not training a neural network on huge numbers of samples, this should put our MAE of 0.631 eV in perspective.
# - We see a similar story for our RMSE, which is 0.852 eV.
# - The Mean Absolute Percent Error (MAPE) is high, but this is because we have 0-valued entries in the dataset - this is why this metric is generally avoided in the case of data with 0s in their values (it also tends to cause models to underestinate when used as a loss function, which is another reason we don't use it as our loss function).
# - Finally, we see that our R2 is 0.735, so our test set predictions are at least correlated with our dataset.

# %%
def rmse(y_true, y_pred):
    mse = sklearn.metrics.mean_squared_error(y_true=y_true, y_pred=y_pred)
    rmse = np.sqrt(abs(mse))
    return rmse

metrics = {
    'MaxError': sklearn.metrics.max_error,
    'MAE': sklearn.metrics.mean_absolute_error,
    'MSE': sklearn.metrics.mean_squared_error,
    'RMSE': rmse,
    'MAPE': sklearn.metrics.mean_absolute_percentage_error,
    'R2': sklearn.metrics.r2_score
}

y_pred_test = best_reg.predict(test_x_reg)
for key, fun in metrics.items():
    value = fun(y_true=test_y_reg, y_pred=y_pred_test)
    print(key,np.round(value,3))
# Out:
# MaxError 3.851
# MAE 0.631
# MSE 0.727
# RMSE 0.852
# MAPE 646627325416641.8
# R2 0.735

# %% [markdown]
# # Regression - Feature Importances
#
# Finally, in the below plot we will list the feature importances of our XGBoost model. Here are a few of the most-important features:
# 1. `var:en_pauling` is a property from XenonPy. It is derived by looking at the tabulated pauling electronegativity of each element in the system (e.g. a system containing NaCl would look at the electronegativity of Na and the electronegativity of Cl). The `var` in front tells us that this version of the feature chooses the variance amongst the electronegativities in each elemental system.
# 2. `max:density` is another XenonPy property. As is the case with all the Xenonpy descriptors we use in this notebook, it is derived by looking at tabulated values for each element in the system. In this case, we take the maximum of the elemntal densities.
# 3. `max:evaporation_heat` is yet another XenonPy descriptor, and is the maximum of the elemental heats of evaporation.

# %%
n_importances = 20
importances = list(zip(best_reg[1].feature_importances_, xenonpy_matminer_descriptors))

sorted_importances = list(sorted(importances, key=lambda i: -i[0]))



plt.barh(range(n_importances), [imp[0] for imp in sorted_importances[:n_importances]])
plt.yticks(range(n_importances), [imp[1] for imp in sorted_importances[:n_importances]])
plt.ylabel("Feature")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.savefig("Importances.jpeg")

# %% [markdown]
# # Conclusions
#
# Overall, in this notebook we:
#
# 1. Trained a classifier to predict whether a material is likely to be a metal or a nonmetal, with very good performance.
# 2. Identified that our data seems to be Tweedie-Distributed once we remove the nonmetals - which might be contributing to some of the error in the model (the high density of points at 0 eV).
# 3. Trained a regression model to predict the bandgap, with MAE comparable to a graph convolutional neural network that had been trained to address the bandgap of similar materials.
# 4. Identified several features important to the prediction of the bandgap, as determined by the importance score of our XGBoost model.

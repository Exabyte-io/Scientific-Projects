# %% [markdown]
# # Metal Classifier
#
# In this notebook, we train an XGBoost classifier to predict whether a system is metallic or not (bandgap <0.1 eV), and use this as an automated means of cleaning our dataset.
#
# At the end, we assess model performance, and observe that our data is largely Tweedie-distributed once we remove the metallic systems.

# %%
import copy

import pandas as pd
import numpy as np
import optuna
import xgboost
import imblearn.over_sampling
import sklearn.model_selection
import dscribe.descriptors
import tqdm
import sklearn.pipeline

import functools

import matplotlib.pyplot as plt
import sklearn.impute
import seaborn as sns

import sys
sys.path.append("../../")
import DigitalEcosystem.utils.figures

tqdm.tqdm.pandas()

# %%
# Random seeds for reproducibility
RANDOM_SEED = 1234
import random
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # Read in the Dataset

# %%
# Load up the data
data_path = "../httpot/full_featurized_data.pkl"
data = pd.read_pickle(data_path)

cols_to_drop = ['formula',
                'discovery_process (unitless)',
                'potcars (unitless)',
                'is_hubbard (unitless)',
                'energy_per_atom (eV)',
                'exfoliation_energy_per_atom (eV/atom)',
                'is_bandgap_direct (unitless)',
                'is_metal (unitless)',
                'energy_vdw_per_atom (eV/atom)',
                'total_magnetization (Bohr Magneton)']
target_column = ['bandgap (eV)']
matpedia_id = ['2dm_id (unitless)']
atoms_col = ['atoms_object (unitless)']

# %% [markdown]
# # Featurization
#
# Here, we use the Sine Matrix eigenspectrum (DScribe Documentation here: [Link](https://singroup.github.io/dscribe/0.3.x/tutorials/sine_matrix.html)) as our input feature to determine metallicity. We'd also tried the Ewald Summation Matrix eigenspectrum (DScribe Documentation here: [Link](https://singroup.github.io/dscribe/latest/tutorials/descriptors/ewald_sum_matrix.html)), but found that the Sine Matrix led to better performnance.

# %%
# Generate the Sine Matrix Fingerprint
max_atoms = max(data['atoms_object (unitless)'].apply(len))
sine_eigenspectrum = dscribe.descriptors.SineMatrix(n_atoms_max=max_atoms,
                                                    permutation='eigenspectrum',
                                                    sparse=False)
data['sine_matrix'] = data['atoms_object (unitless)'].progress_apply(lambda atoms: np.real(sine_eigenspectrum.create(atoms)))
# Out:
# 100%|██████████| 6351/6351 [00:11<00:00, 575.51it/s]

# %% [markdown]
# Next, we'll label our data. We'll say that it's a metal if its DFT bandgap is less than 0.1 eV.

# %%
# Manually label metals/nonmetals
bandgap_cutoff = 0.1

data['metal'] = data['bandgap (eV)'] < bandgap_cutoff
train, test = sklearn.model_selection.train_test_split(data, test_size=0.1, stratify=data['metal'], random_state=RANDOM_SEED)

# %% [markdown]
# # Train/Test Split
# Then, we'll split up our data into a training and testing set. We'll stratify our dataset to ensure the same proportion of metals are found in both the training and test set.

# %%
# Pull out the X and Y values
def get_x_y(df):
    x = np.vstack(df['sine_matrix'])
    y = df['metal'].apply(int).to_numpy()
    return x,y
train_x, train_y = get_x_y(train)
test_x, test_y = get_x_y(test)

# %% [markdown]
# # K-Means SMOTE
# At this point, our dataset is slightly imbalanced. To address this, we'll use the K-means variation of SMOTE (Imbalanced-Learn Documentation here: [Link](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.KMeansSMOTE.html)). This is a variation on SMOTE that first performs the K-Means algorithm to generate class labels within the minority class, and then upsamples those. It's shown very promising performance for imbalanced classification problems compared to the original SMOTE algorithm (Original publication hosted at https://arxiv.org/abs/1711.00837).
#
# To avoid contaminating our test set with information about the training set, we perform K-means SMOTE *after* the train/test split.

# %%
# Upsample the training set with SMOTE
knn_smote = imblearn.over_sampling.KMeansSMOTE(
    random_state=RANDOM_SEED,
    k_neighbors = 4
)
res_x, res_y = knn_smote.fit_resample(train_x, train_y)

# %% [markdown]
# # Hyperparameter Optimization
#
# For this work, we'll use an XGBoost classifier. Several of its most important hyperparameters are tuned via Optuna, a Bayesian optimization framework implented in Python.
#
# In addition to optimizing the hyperparameters, we'll also investigate the use of a scaler. Optuna can choose from the following options:
# 1. No scaler being applied
# 2. A Min/Max scaler
# 3. A StandardScaler

# %%
current_pipeline = None
best_pipeline = None

def keep_best_bandgap_model(study, trial):
    """
    Records the best bandgap model found so far
    """
    global best_pipeline
    try:
        if study.best_trial == trial:
            best_pipeline = current_pipeline
    except ValueError:
        pass

def objective(trial: optuna.Trial):
    global current_pipeline

    objective_train_x, objective_validation_x, objective_train_y, objective_validation_y = sklearn.model_selection.train_test_split(res_x, res_y, test_size=0.2)

    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0, 1),
        'min_split_loss': trial.suggest_float('min_split_loss', 0, 1),
        'max_depth': trial.suggest_int('max_depth', 1, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 2),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 2)
    }

    scalers = {
        "StandardScaler": sklearn.preprocessing.StandardScaler(),
        "MinMaxScaler": sklearn.preprocessing.MinMaxScaler()
    }

    scaler = trial.suggest_categorical('scaler', scalers.keys())

    current_pipeline = sklearn.pipeline.Pipeline([
        (scaler, scalers[scaler]),
        ("XGB_Classifier", xgboost.sklearn.XGBClassifier(**params,
                                               n_estimators=100,
                                               objective='binary:logistic',
                                               use_label_encoder=False,
                                               random_state=RANDOM_SEED),)
    ])

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, 'validation_0-auc')

    current_pipeline.fit(X=objective_train_x, y=objective_train_y,
                         **{
                            'XGB_Classifier__eval_set': [[objective_validation_x, objective_validation_y]],
                            'XGB_Classifier__eval_metric': 'auc',
                            'XGB_Classifier__early_stopping_rounds': 5,
                            'XGB_Classifier__callbacks': [pruning_callback],
                            'XGB_Classifier__verbose': False
                         })

    preds = current_pipeline.predict(objective_validation_x)
    pred_labels = np.rint(preds)
    f1 = sklearn.metrics.f1_score(objective_validation_y, pred_labels)

    return f1

# %% [markdown]
# We'll run Optuna using its TPE Sampler (the default; documentation here: [Link](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.samplers.TPESampler.html)) with a random seed supplied. Additionally, we'll use the HyperBand pruner to prune trials that are not promising (Documentation link here: [Link](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.pruners.HyperbandPruner.html)).
#
# We choose the HyperBand pruner because it's demonstrated accelerate convergence faster than many of the other pruning techniques available in Optuna: [Blogpost Link](https://tech.preferred.jp/en/blog/how-we-implement-hyperband-in-optuna/)

# %%
study = optuna.create_study(
    sampler = optuna.samplers.TPESampler(
        seed=RANDOM_SEED,
        warn_independent_sampling=True,
        consider_endpoints=True,
    ),
    pruner = optuna.pruners.HyperbandPruner(
        min_resource=1,
        max_resource=100),
    direction='maximize',
)
# Out:
# [I 2021-08-09 16:10:41,379] A new study created in memory with name: no-name-fe82af10-b943-4528-9d69-c264eeba0648

# %%
study.optimize(objective, n_trials=1000, callbacks=[keep_best_bandgap_model])
# Out:
# [I 2021-08-09 16:10:42,123] Trial 0 finished with value: 0.7352697095435685 and parameters: {'learning_rate': 0.1915194503788923, 'min_split_loss': 0.6221087710398319, 'max_depth': 44, 'min_child_weight': 7.853585837137692, 'reg_lambda': 1.559951616237607, 'reg_alpha': 0.5451852105652832, 'scaler': 'MinMaxScaler'}. Best is trial 0 with value: 0.7352697095435685.
# [I 2021-08-09 16:10:42,152] Trial 1 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,178] Trial 2 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,202] Trial 3 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,279] Trial 4 finished with value: 0.7415540540540541 and parameters: {'learning_rate': 0.8021476420801591, 'min_split_loss': 0.14376682451456457, 'max_depth': 71, 'min_child_weight': 7.045813081895726, 'reg_lambda': 0.43758421134817715, 'reg_alpha': 1.84973525723113, 'scaler': 'MinMaxScaler'}. Best is trial 4 with value: 0.7415540540540541.
# [I 2021-08-09 16:10:42,331] Trial 5 finished with value: 0.6666666666666666 and parameters: {'learning_rate': 0.0598092227798519, 'min_split_loss': 0.18428708381381365, 'max_depth': 5, 'min_child_weight': 6.748809435823302, 'reg_lambda': 1.1892495598688977, 'reg_alpha': 1.0666203259975011, 'scaler': 'MinMaxScaler'}. Best is trial 4 with value: 0.7415540540540541.
# [I 2021-08-09 16:10:42,512] Trial 6 finished with value: 0.7580919931856899 and parameters: {'learning_rate': 0.329668445620915, 'min_split_loss': 0.5029668331126184, 'max_depth': 12, 'min_child_weight': 6.071937062184846, 'reg_lambda': 1.1318892861010628, 'reg_alpha': 0.01352812398000558, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:42,539] Trial 7 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,561] Trial 8 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,663] Trial 9 finished with value: 0.7424111014744146 and parameters: {'learning_rate': 0.4716325343203678, 'min_split_loss': 0.1071268171938663, 'max_depth': 23, 'min_child_weight': 8.999651948366754, 'reg_lambda': 0.8335070756053864, 'reg_alpha': 1.0717033250632317, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:42,727] Trial 10 finished with value: 0.730185497470489 and parameters: {'learning_rate': 0.4368931721756102, 'min_split_loss': 0.6121489970657575, 'max_depth': 92, 'min_child_weight': 6.2573666996253525, 'reg_lambda': 1.4119951301635465, 'reg_alpha': 0.29966743197985446, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:42,762] Trial 11 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:42,789] Trial 12 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:42,806] Trial 13 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,833] Trial 14 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:42,921] Trial 15 finished with value: 0.7383863080684596 and parameters: {'learning_rate': 0.7266584615621408, 'min_split_loss': 0.9000878368097077, 'max_depth': 78, 'min_child_weight': 5.991547806042924, 'reg_lambda': 0.5822504897957497, 'reg_alpha': 0.30279052881486423, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:42,952] Trial 16 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:43,050] Trial 17 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:10:43,083] Trial 18 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:43,127] Trial 19 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:43,219] Trial 20 finished with value: 0.6782911944202267 and parameters: {'learning_rate': 0.6928010970560983, 'min_split_loss': 0.7980867042239794, 'max_depth': 21, 'min_child_weight': 4.399663492979241, 'reg_lambda': 1.3996356256301008, 'reg_alpha': 1.8002953029615436, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:43,325] Trial 21 finished with value: 0.723728813559322 and parameters: {'learning_rate': 0.25565328643413965, 'min_split_loss': 0.10831149418272878, 'max_depth': 78, 'min_child_weight': 7.82477992600202, 'reg_lambda': 1.5232078286149882, 'reg_alpha': 1.8288062265386476, 'scaler': 'StandardScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:43,498] Trial 22 finished with value: 0.7457912457912457 and parameters: {'learning_rate': 0.658083611788181, 'min_split_loss': 0.7421406140103293, 'max_depth': 25, 'min_child_weight': 0.2397466594100699, 'reg_lambda': 1.4604866150761706, 'reg_alpha': 1.9396714530586985, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:43,704] Trial 23 finished with value: 0.7577319587628867 and parameters: {'learning_rate': 0.2289344999679703, 'min_split_loss': 0.45490419255614784, 'max_depth': 61, 'min_child_weight': 1.0188868512890452, 'reg_lambda': 1.7869121116508186, 'reg_alpha': 0.8094639162170426, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:43,750] Trial 24 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:43,845] Trial 25 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:43,926] Trial 26 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:43,969] Trial 27 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:44,086] Trial 28 finished with value: 0.7375527426160337 and parameters: {'learning_rate': 0.3656190873671856, 'min_split_loss': 0.8016025985027602, 'max_depth': 79, 'min_child_weight': 7.01355379236693, 'reg_lambda': 1.2455531732063982, 'reg_alpha': 0.9873652914942241, 'scaler': 'StandardScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:44,121] Trial 29 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:44,175] Trial 30 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:44,227] Trial 31 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:44,287] Trial 32 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:44,363] Trial 33 finished with value: 0.7032040472175379 and parameters: {'learning_rate': 0.9790388199339376, 'min_split_loss': 0.881232246338927, 'max_depth': 63, 'min_child_weight': 9.304865334026656, 'reg_lambda': 1.4495799062048778, 'reg_alpha': 1.4333557721107124, 'scaler': 'MinMaxScaler'}. Best is trial 6 with value: 0.7580919931856899.
# [I 2021-08-09 16:10:44,449] Trial 34 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:10:44,511] Trial 35 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:44,561] Trial 36 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:44,606] Trial 37 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:44,652] Trial 38 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:44,698] Trial 39 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:44,735] Trial 40 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:44,810] Trial 41 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:45,006] Trial 42 finished with value: 0.7904761904761903 and parameters: {'learning_rate': 0.7113200683713711, 'min_split_loss': 0.5382989273102106, 'max_depth': 100, 'min_child_weight': 3.927613692841248, 'reg_lambda': 0.22258882196230112, 'reg_alpha': 0.37898222469456944, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:45,074] Trial 43 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:45,116] Trial 44 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:45,162] Trial 45 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:45,324] Trial 46 finished with value: 0.7090592334494773 and parameters: {'learning_rate': 0.016022036026714787, 'min_split_loss': 0.5399710820729988, 'max_depth': 15, 'min_child_weight': 0.46397177262994144, 'reg_lambda': 1.4759805937257224, 'reg_alpha': 0.6816717654920917, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:45,418] Trial 47 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:45,471] Trial 48 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:45,647] Trial 49 finished with value: 0.768860353130016 and parameters: {'learning_rate': 0.4044732747444349, 'min_split_loss': 0.8724198073970881, 'max_depth': 36, 'min_child_weight': 5.797319467164344, 'reg_lambda': 1.3044731307476334, 'reg_alpha': 1.3410327522443029, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:45,722] Trial 50 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:45,782] Trial 51 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:45,931] Trial 52 finished with value: 0.745928338762215 and parameters: {'learning_rate': 0.7193724841842117, 'min_split_loss': 0.5481668305232565, 'max_depth': 79, 'min_child_weight': 2.100181858220778, 'reg_lambda': 0.3646558778910838, 'reg_alpha': 0.03773591083654504, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:46,044] Trial 53 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:10:46,193] Trial 54 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:10:46,237] Trial 55 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:46,295] Trial 56 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:46,424] Trial 57 finished with value: 0.7342908438061042 and parameters: {'learning_rate': 0.35174682158758874, 'min_split_loss': 0.6301331125022921, 'max_depth': 36, 'min_child_weight': 2.1281993764846496, 'reg_lambda': 0.44663844624530435, 'reg_alpha': 0.8391275834616554, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:46,468] Trial 58 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:46,577] Trial 59 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:10:46,637] Trial 60 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:46,691] Trial 61 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10
pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:10:57,283] Trial 155 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:57,350] Trial 156 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:57,410] Trial 157 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:57,476] Trial 158 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:57,559] Trial 159 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:57,789] Trial 160 finished with value: 0.7454702329594479 and parameters: {'learning_rate': 0.4607376637027527, 'min_split_loss': 0.8167558712560374, 'max_depth': 28, 'min_child_weight': 9.619416898695631, 'reg_lambda': 0.6511446859639805, 'reg_alpha': 0.36795556097877924, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:57,864] Trial 161 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:57,950] Trial 162 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:58,060] Trial 163 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:58,128] Trial 164 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:58,227] Trial 165 finished with value: 0.71875 and parameters: {'learning_rate': 0.3952608273022642, 'min_split_loss': 0.47270912501449464, 'max_depth': 57, 'min_child_weight': 7.3071286208284025, 'reg_lambda': 0.6805095734476482, 'reg_alpha': 0.2262483276109143, 'scaler': 'MinMaxScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:58,320] Trial 166 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:58,371] Trial 167 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:58,446] Trial 168 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:58,517] Trial 169 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:58,620] Trial 170 finished with value: 0.6990116801437556 and parameters: {'learning_rate': 0.07069617875044265, 'min_split_loss': 0.15762308631249733, 'max_depth': 17, 'min_child_weight': 2.8363708226213924, 'reg_lambda': 1.073412051128132, 'reg_alpha': 1.546477429786421, 'scaler': 'StandardScaler'}. Best is trial 42 with value: 0.7904761904761903.
# [I 2021-08-09 16:10:59,134] Trial 171 finished with value: 0.791769547325103 and parameters: {'learning_rate': 0.11646523825307442, 'min_split_loss': 0.6697886796367318, 'max_depth': 24, 'min_child_weight': 0.33587595370965995, 'reg_lambda': 1.9045071310029442, 'reg_alpha': 0.005685952930750471, 'scaler': 'MinMaxScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:10:59,209] Trial 172 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:59,279] Trial 173 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:10:59,339] Trial 174 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:59,405] Trial 175 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:59,528] Trial 176 finished with value: 0.7218045112781954 and parameters: {'learning_rate': 0.07797165877781265, 'min_split_loss': 0.522638129529294, 'max_depth': 47, 'min_child_weight': 3.5243693396988878, 'reg_lambda': 0.03537269208706684, 'reg_alpha': 0.7677252909731527, 'scaler': 'MinMaxScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:10:59,597] Trial 177 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:59,715] Trial 178 finished with value: 0.7001703577512778 and parameters: {'learning_rate': 0.8526022402545531, 'min_split_loss': 0.597955371524427, 'max_depth': 70, 'min_child_weight': 5.371766731466012, 'reg_lambda': 1.778460166931392, 'reg_alpha': 0.10453285251363931, 'scaler': 'StandardScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:10:59,785] Trial 179 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:10:59,940] Trial 180 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:11:00,025] Trial 181 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:00,100] Trial 182 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:00,192] Trial 183 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:00,345] Trial 184 finished with value: 0.7495621716287215 and parameters: {'learning_rate': 0.41577314191785397, 'min_split_loss': 0.42152770756889335, 'max_depth': 70, 'min_child_weight': 4.302474141190517, 'reg_lambda': 1.8878017203237394, 'reg_alpha': 0.6550231540699057, 'scaler': 'MinMaxScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:11:00,430] Trial 185 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:00,638] Trial 186 finished with value: 0.7669172932330828 and parameters: {'learning_rate': 0.5563327179545727, 'min_split_loss': 0.9004526170356961, 'max_depth': 57, 'min_child_weight': 1.5338721146121355, 'reg_lambda': 0.4133393669975883, 'reg_alpha': 0.7957600620189115, 'scaler': 'MinMaxScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:11:00,720] Trial 187 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:00,778] Trial 188 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:11:00,860] Trial 189 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:00,963] Trial 190 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:01,095] Trial 191 finished with value: 0.7188306104901118 and parameters: {'learning_rate': 0.45918340728030166, 'min_split_loss': 0.6587276309798678, 'max_depth': 70, 'min_child_weight': 6.692961529668953, 'reg_lambda': 0.8354167619516426, 'reg_alpha': 0.479478415182118, 'scaler': 'MinMaxScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:11
pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:12,984] Trial 281 finished with value: 0.717948717948718 and parameters: {'learning_rate': 0.8302457318410754, 'min_split_loss': 0.7447641766130533, 'max_depth': 59, 'min_child_weight': 4.928678525654821, 'reg_lambda': 0.974711759682386, 'reg_alpha': 0.5334813918458408, 'scaler': 'MinMaxScaler'}. Best is trial 171 with value: 0.791769547325103.
# [I 2021-08-09 16:11:13,052] Trial 282 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:11:13,128] Trial 283 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:11:13,184] Trial 284 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:11:13,253] Trial 285 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:11:13,331] Trial 286 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:13,414] Trial 287 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:11:13,505] Trial 288 pruned. Trial was pruned at iteration 3.
# ...
# [I 2021-08-09 16:12:35,775] Trial 901 finished with value: 0.7612456747404844 and parameters: {'learning_rate': 0.5869703152257566, 'min_split_loss': 0.9070399004081885, 'max_depth': 63, 'min_child_weight': 9.453543335011334, 'reg_lambda': 0.508516374794104, 'reg_alpha': 0.8421263865076313, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:35,892] Trial 902 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:35,996] Trial 903 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:36,257] Trial 904 finished with value: 0.769742310889443 and parameters: {'learning_rate': 0.2946076325270734, 'min_split_loss': 0.9114718455057347, 'max_depth': 26, 'min_child_weight': 1.2996714016316986, 'reg_lambda': 1.7549863577626188, 'reg_alpha': 0.07582741760894567, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:36,438] Trial 905 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:12:36,742] Trial 906 finished with value: 0.7646544181977253 and parameters: {'learning_rate': 0.39123687521201045, 'min_split_loss': 0.8025600210388382, 'max_depth': 61, 'min_child_weight': 4.953953048852262, 'reg_lambda': 0.49391436831340996, 'reg_alpha': 0.8264765995773924, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:36,908] Trial 907 finished with value: 0.7316666666666667 and parameters: {'learning_rate': 0.5158390610118317, 'min_split_loss': 0.560457179009606, 'max_depth': 70, 'min_child_weight': 9.84815026096375, 'reg_lambda': 1.9381579482300217, 'reg_alpha': 0.043409414299624985, 'scaler': 'StandardScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:37,068] Trial 908 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:37,352] Trial 909 finished with value: 0.7771428571428572 and parameters: {'learning_rate': 0.3805305550786649, 'min_split_loss': 0.8014972345931968, 'max_depth': 10, 'min_child_weight': 0.7738353329806404, 'reg_lambda': 0.19732350002788324, 'reg_alpha': 1.4314142191503887, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:37,459] Trial 910 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:37,721] Trial 911 finished with value: 0.7551724137931034 and parameters: {'learning_rate': 0.28445391180605994, 'min_split_loss': 0.4991619830334882, 'max_depth': 65, 'min_child_weight': 2.397649776348951, 'reg_lambda': 1.764406341189805, 'reg_alpha': 0.14604315121930528, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:37,852] Trial 912 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:38,193] Trial 913 finished with value: 0.7525951557093424 and parameters: {'learning_rate': 0.7827370858023379, 'min_split_loss': 0.636788298610216, 'max_depth': 48, 'min_child_weight': 0.780476672454543, 'reg_lambda': 1.8254156587054087, 'reg_alpha': 1.8205050636233184, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:38,295] Trial 914 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:38,397] Trial 915 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:38,565] Trial 916 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:12:38,702] Trial 917 finished with value: 0.7067307692307693 and parameters: {'learning_rate': 0.3624832553016253, 'min_split_loss': 0.7897064739412311, 'max_depth': 2, 'min_child_weight': 0.7212658061429953, 'reg_lambda': 0.4255038927839912, 'reg_alpha': 1.2840154385863045, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:38,815] Trial 918 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:39,052] Trial 919 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:12:39,201] Trial 920 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:39,325] Trial 921 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:39,452] Trial 922 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:39,570] Trial 923 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12
pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:44,665] Trial 960 finished with value: 0.7485380116959065 and parameters: {'learning_rate': 0.3540360853547963, 'min_split_loss': 0.8077977936617833, 'max_depth': 32, 'min_child_weight': 0.5380915076289152, 'reg_lambda': 1.8483964631433285, 'reg_alpha': 1.5553610558072952, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:44,785] Trial 961 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:45,139] Trial 962 finished with value: 0.7537437603993344 and parameters: {'learning_rate': 0.3710343373372846, 'min_split_loss': 0.9256592524235729, 'max_depth': 34, 'min_child_weight': 0.23732398965663073, 'reg_lambda': 1.8110294787258785, 'reg_alpha': 1.4522275005736576, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:45,446] Trial 963 finished with value: 0.7594936708860759 and parameters: {'learning_rate': 0.08928298008276359, 'min_split_loss': 0.8389197384446743, 'max_depth': 55, 'min_child_weight': 1.4902592797324767, 'reg_lambda': 0.6531811746299632, 'reg_alpha': 1.0701103219861745, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:45,575] Trial 964 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:45,766] Trial 965 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:12:46,002] Trial 966 finished with value: 0.7769784172661869 and parameters: {'learning_rate': 0.5068798827438916, 'min_split_loss': 0.8052674452525248, 'max_depth': 63, 'min_child_weight': 3.46610642088996, 'reg_lambda': 0.8820978943477001, 'reg_alpha': 1.4912856498892926, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:46,127] Trial 967 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:46,273] Trial 968 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:46,415] Trial 969 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:46,655] Trial 970 finished with value: 0.7275720164609054 and parameters: {'learning_rate': 0.7423266715160988, 'min_split_loss': 0.8355071717295601, 'max_depth': 76, 'min_child_weight': 3.238699822234502, 'reg_lambda': 1.7062117842513858, 'reg_alpha': 0.41447419682342623, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:46,802] Trial 971 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:46,980] Trial 972 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:47,312] Trial 973 finished with value: 0.7687074829931974 and parameters: {'learning_rate': 0.8970663142592123, 'min_split_loss': 0.9227953327416962, 'max_depth': 62, 'min_child_weight': 2.6115153476901467, 'reg_lambda': 1.9925148732122335, 'reg_alpha': 0.25475181199695673, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:47,659] Trial 974 finished with value: 0.7654941373534339 and parameters: {'learning_rate': 0.3948017723654222, 'min_split_loss': 0.7271827093700765, 'max_depth': 37, 'min_child_weight': 0.1410840134450596, 'reg_lambda': 1.8105896958724916, 'reg_alpha': 1.4166017584688606, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:47,817] Trial 975 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:48,083] Trial 976 finished with value: 0.7152209492635024 and parameters: {'learning_rate': 0.9907166823322227, 'min_split_loss': 0.818165659074284, 'max_depth': 67, 'min_child_weight': 3.9684050987515382, 'reg_lambda': 1.6655571459673062, 'reg_alpha': 0.8324297246785831, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:48,283] Trial 977 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:48,458] Trial 978 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:48,600] Trial 979 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:48,915] Trial 980 finished with value: 0.7530017152658661 and parameters: {'learning_rate': 0.5557119031765321, 'min_split_loss': 0.7400381308151334, 'max_depth': 65, 'min_child_weight': 3.440101626379482, 'reg_lambda': 0.9955954831199105, 'reg_alpha': 1.5728805743208243, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:49,044] Trial 981 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:49,266] Trial 982 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:49,425] Trial 983 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:49,657] Trial 984 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:49,805] Trial 985 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:49,966] Trial 986 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:50,149] Trial 987 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:50,492] Trial 988 finished with value: 0.7683235046335298 and parameters: {'learning_rate': 0.8504869145510856, 'min_split_loss': 0.8970476395170475, 'max_depth': 84, 'min_child_weight': 2.8499670739052725, 'reg_lambda': 1.5109477082509615, 'reg_alpha': 1.298061121333448, 'scaler': 'MinMaxScaler'}. Best is trial 341 with value: 0.7934959349593496.
# [I 2021-08-09 16:12:50,645] Trial 989 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:12:50,868] Trial 990 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:12:51,051] Trial 991 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:51,174] Trial 992 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:51,294] Trial 993 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:51,438] Trial 994 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:51,567] Trial 995 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:51,697] Trial 996 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:51,817] Trial 997 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:12:51,967] Trial 998 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:12:52,198] Trial 999 pruned. Trial was pruned at iteration 9.

# %% [markdown]
# # ROC Curves
#
# To assess model performance, we'll print out some ROC curves here.
#
# Although we hold out a validation set in our objective function, we do not retrain the model on the entire training set, as this validation set was also used to control the early stopping of our XGBoost model (and thus helps guard against overfitting).
#
# Overall, we see generally good results for both our training set and our testing set.

# %%
plot_roc = functools.partial(DigitalEcosystem.utils.figures.plot_roc, classifier=best_pipeline)

plot_roc(train_x, train_y, "Training")
plot_roc(test_x, test_y, "Test")

# %% [markdown]
# # Confusion Matrices
#
# For a more fine-grained picture of our model's performance, we also draw confusion matrices here.
#
# Overall, our classification is slightly biased towards under-prediction of the number of metals in the dataset when the model's probability cutoff is set to 0.5. Although we did not tune this cutoff, the process would be easy: we could simply lower the probability at-which something is considered to be a metal until the number of misclassified metals and nonmetals were equal in the training set.
#
# A few metrics of the model's performance, derived from the above ROC curves and the below confusion matrices, are summarized in the below table.
#
# | Metric   | Training Set | Test Set |
# |----------|--------------|----------|
# | TPR      | 0.892        | 0.766    |
# | FPR      | 0.098        | 0.232    |
# | Accuracy | 0.897        | 0.767    |
# | F1 Score | 0.902        | 0.784    |
# | ROC AUC  | 0.956        | 0.848    |
#
# Overall, we see good performnace in both our training and testing set, with similar error rates in both - which is a good indication that our model generalizes well to the testing set.

# %%
CUTOFF = 0.5


draw_confusion_matrix = functools.partial(DigitalEcosystem.utils.figures.draw_confusion_matrix,
                                          classifier=best_pipeline,
                                          cutoff=CUTOFF)

draw_confusion_matrix(train_x, train_y, "Training")
draw_confusion_matrix(test_x, test_y, "Test")

# %% [markdown]
# # Nonmetal Bandgap Regression
#
# Next, we'll move to the next step of our pipeline: predicting the bandgap of nonmetals.
#
# We'll use our trained classifier to label the dataset as "metal" or "nonmetal."

# %%
train['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(train_x)[:,1] > CUTOFF)
test['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(test_x)[:,1] > CUTOFF)
# Out:
# <ipython-input-15-d6db99a82058>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(train_x)[:,1] > CUTOFF)
# <ipython-input-15-d6db99a82058>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['pred_metal'] = copy.deepcopy(best_pipeline.predict_proba(test_x)[:,1] > CUTOFF)

# %% [markdown]
# Next, we'll separate out the predicted nonmetals from our training and testing set.

# %%
train_metals = train[train['pred_metal'] == True]
train_nonmetals = train[train['pred_metal'] != True]

test_metals = test[test['pred_metal'] == True]
test_nonmetals = test[test['pred_metal'] != True]

# %% [markdown]
# # Bandgap Distribution
#
# Before we perform the regression, let's also investigate the distribution of our data.
#
# ## Entire Dataset
#
# First, we look at the bandgap of all data in our dataset (including metals and nonmetals). We see a very large spike at approximately 0 bandgap, followed by a tail of wider bandgaps.

# %%
bins = np.arange(0,max(data['bandgap (eV)']), 0.5)
stat='density'

draw_train_test_histplot = functools.partial(DigitalEcosystem.utils.figures.save_train_test_histplot,
                                             column='bandgap (eV)',
                                             stat=stat,
                                             bins=bins)

draw_train_test_histplot(train, test,
                         "All Data",
                         "FullDatasetBandgapHistogram.jpeg")

# %% [markdown]
# ## Predicted-Nonmetals Only
#
# Next, we'll take a look at just rows from training and testing set which were labeled as nonmetals by our classifier.
#
# We see that our data distribution has changed - the training set and testing set seem to be a a mixture between a Poisson distribution and a Gamma distribution - this is the classic Tweedie distribution (Wikipedia article: [Link](https://en.wikipedia.org/wiki/Tweedie_distribution)).

# %%
draw_train_test_histplot(train_nonmetals,
                         test_nonmetals,
                         "Classififed as Nonmetals",
                         "NormalHistplot.jpeg")

# %% [markdown]
# ## Predicted Metals Only
#
# Finally, we'll investigate our predicted metals and nonmetals. We see that, barring a few exceptions, materials that are predicted to be a metal at least tend to have a low bandgap.

# %%
draw_train_test_histplot(train_metals,
                         test_metals,
                         "Classified as Metals",
                         "MetalHistplot.jpeg")

# %% [markdown]
# # Regression - Features
#
# Before we start doing any work with regression, we need to choose a set of features. Because we've been finding success in the past in this problem with the Xenonpy and Matminer-derived descriptors, we'll go ahead and extract those from our dataset.

# %%
xenonpy_descriptors = [col for col in data.columns if ":" in col]
matminer_descriptors = [
    'bond_length_average',
    'bond_angle_average',
    'average_cn',
    'global_instability',
    'perimeter_area_ratio',
    'ewald_energy_per_atom',
    'structural complexity per atom',
    'structural complexity per cell',
    'n_symmetry_ops'

]
xenonpy_matminer_descriptors = xenonpy_descriptors + matminer_descriptors#%%
target = ['bandgap (eV)']

# %% [markdown]
# Next, we'll separate out our X and Y columns, and we'll use Numpy to remove any NaN values that made their way into the dataset.
#
# This is an area of improvement, as we could have also imputed the NaN values instead.

# %%
train_x_reg = np.nan_to_num(train_nonmetals[xenonpy_matminer_descriptors].to_numpy())
train_y_reg = np.nan_to_num(train_nonmetals[target].to_numpy())

test_x_reg = np.nan_to_num(test_nonmetals[xenonpy_matminer_descriptors].to_numpy())
test_y_reg = np.nan_to_num(test_nonmetals[target].to_numpy())

# %% [markdown]
# # Tweedie Distribution - Investigation
#
# Finally, before we do our regression, let's revisit the Tweedie distribution we discussed earlier.
#
# The shape of the Tweedie distribution is controlled by a power parameter, which allows it to function as a generalization of a variety of other distributions, including the Poisson, Gamma, Normal, Gaussian, and other distributions. H2O has some very good documentation on this subject: [Link](https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/algo-params/tweedie_variance_power.html#:~:text=Tweedie%20distributions%20are%20a%20family,\)%3D%CF%95%CE%BCpi.).
#
# To estimate the power, we'll walk along powers ranging from 1.0 (Poisson) to almost 2.0 (Gamma), with intermediate powers representing a Tweedie distribution. At each step, we'll take 1,000 bootstrap samples of the dataset and calculate the mean tweedie deviance relative to the mean of the bandgap. We'll take the power that results in the lowest mean tweedie deviance as an estimate of the Tweedie power.
#
# Overall, we find the following results:
#
# | Data Subset     | Optimal Tweedie Power |
# |-----------------|-----------------------|
# | Full Dataset    | 1.0                   |
# | Train Nonmetals | 1.326                 |
# | Test Nonmetals  | 1.202                 |
#
# When we attempt to fit a model on our entire dataset, we see that the data is closest to a Poisson distribution.
#
# When we remove metals and testing set, however, we see that our data shifts to be more Tweedie - Distributed (a power between 1 and 2).Moreover, we see a slight difference in power between our training and testing set - which we can actually see in the above "Classified as Nonmetals" plot, particularly below 2 eV.
#
# This difference in distribution between our training set and testing set is likely to contribute to error in our regression model.

# %%
# Find the power that our data falls under in a tweedie distribution
def get_pow_plot(dist, filename):
    deviances = []
    n_boot_samples = 1000
    mesh_size = 100
    with tqdm.tqdm(total=mesh_size) as pbar:
        for tweedie_deviance_power in np.linspace(1,1.95,num=mesh_size):
            try:
                samples = []
                for i in range(n_boot_samples):
                    boot_sample = np.random.choice(dist, replace=True, size=len(dist))
                    samples.append(sklearn.metrics.mean_tweedie_deviance(y_true=boot_sample,
                                                                         y_pred=[abs(boot_sample.mean())]*len(boot_sample),
                                                                         power=tweedie_deviance_power))
                samp_mean = sum(samples) / len(samples)
                #samp_var = sum([sample - samp_mean for sample in samples])/ len(samples)
                deviances.append([tweedie_deviance_power, samp_mean])
            except ValueError:
                pass
            finally:
                pbar.update(1)

    plt.plot([i[0] for i in deviances],[i[1] for i in deviances], label="Bootstrapped Results")

    best_pow, best_dev = min(deviances, key=lambda i: i[1])
    plt.scatter([best_pow], [best_dev], marker="+", c='k', s=1000, lw=5, label="Minimum")

    plt.xlabel("Tweedie Distribution Power")
    plt.ylabel("Mean Tweedie Deviance")
    plt.title(f"{n_boot_samples} Bootstrap Samples")
    plt.legend()
    plt.savefig(filename)
    print(f"Best Pow is {best_pow} with Tweedie Deviance {best_dev}")
    plt.close()
    return best_pow


get_pow_plot(test_nonmetals['bandgap (eV)'].to_numpy(), "TestNonmetalTweediePower.jpeg")
get_pow_plot(data["bandgap (eV)"].to_numpy(), "FullDatasetTweediePower.jpeg")
best_pow=get_pow_plot(train_nonmetals["bandgap (eV)"].to_numpy(), "TrainNonmetalTweediePower.jpeg")
# Out:
# 100%|██████████| 100/100 [00:24<00:00,  4.15it/s]
# 100%|██████████| 100/100 [01:18<00:00,  1.27it/s]
# 100%|██████████| 100/100 [00:53<00:00,  1.86it/s]
# Best Pow is 1.2015151515151514 with Tweedie Deviance 1.6768544254853925
# Best Pow is 1.0 with Tweedie Deviance 1.8696522485719442
# Best Pow is 1.3262626262626263 with Tweedie Deviance 1.2266815993702445

# %% [markdown]
# # Regression - XGBoost
#
# Finally, we'll train another XGBoost model, this time for regression of the bandgap. We'll again use Optuna to tune a few of the model's hyperparameter (fewer in the interest of time). We'll also just start with a Min/Max scaler, as some previous work we'd done on thi problem indicated good performance when this was used as a scaler versus standardization or not scaling.
#
# We'll finally draw a parity plot of our results.

# %%
current_reg = None
best_reg = None
def keep_best_reg(study, trial):
    global best_reg
    if study.best_trial == trial:
        best_reg = current_reg

#TEST
objective_train_x_reg, objective_validation_x_reg, objective_train_y_reg, objective_validation_y_reg = sklearn.model_selection.train_test_split(
    np.nan_to_num(train_x_reg), train_y_reg, test_size=0.2, random_state=RANDOM_SEED)

def objective(trial: optuna.Trial):
    global current_reg


    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0, 1),
        'min_split_loss': trial.suggest_float('min_split_loss', 0, 2),
        'max_depth': trial.suggest_int('max_depth', 1, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0, 10),
    }

    current_reg = sklearn.pipeline.Pipeline([
        ("Scaler", sklearn.preprocessing.MinMaxScaler()),
        ("XGB_Regressor", xgboost.sklearn.XGBRegressor(**params,
                                               n_estimators=100,
                                               objective='reg:squarederror',
                                               random_state=RANDOM_SEED),)
    ])

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'validation_0-poisson-nloglik')
    current_reg.fit(X=objective_train_x_reg, y=objective_train_y_reg,
                         **{
                            'XGB_Regressor__eval_set': [[objective_validation_x_reg, objective_validation_y_reg]],
                            'XGB_Regressor__eval_metric': 'poisson-nloglik',
                            'XGB_Regressor__early_stopping_rounds': 50,
                            'XGB_Regressor__callbacks': [pruning_callback],
                            'XGB_Regressor__verbose': False
                         })

    score = sklearn.metrics.mean_poisson_deviance(
        y_true=objective_validation_y_reg,
        y_pred=abs(current_reg.predict(objective_validation_x_reg)),
    )

    return score

reg_study = optuna.create_study(
    sampler = optuna.samplers.TPESampler(
        seed = RANDOM_SEED,
        warn_independent_sampling = True,
        consider_endpoints = True
    ),
    pruner = optuna.pruners.HyperbandPruner(
        min_resource=1,
        max_resource=100),
    direction='minimize'
)

reg_study.optimize(func=objective, n_trials=500, callbacks=[keep_best_reg])

DigitalEcosystem.utils.figures.save_parity_plot(train_x_reg,
                                                test_x_reg,
                                                train_y_reg,
                                                test_y_reg,
                                                best_reg,
                                                "Bandgap (eV)",
                                                "parity.jpeg")
# Out:
# [I 2021-08-09 16:18:20,611] A new study created in memory with name: no-name-1f4396d1-f8e7-4682-9cea-cc702ef59544
# [I 2021-08-09 16:18:24,101] Trial 0 finished with value: 0.5872363030035983 and parameters: {'learning_rate': 0.1915194503788923, 'min_split_loss': 1.2442175420796637, 'max_depth': 44, 'min_child_weight': 7.853585837137692}. Best is trial 0 with value: 0.5872363030035983.
# [I 2021-08-09 16:18:27,387] Trial 1 finished with value: 0.988923053875419 and parameters: {'learning_rate': 0.7799758081188035, 'min_split_loss': 0.5451852105652832, 'max_depth': 28, 'min_child_weight': 8.018721775350192}. Best is trial 0 with value: 0.5872363030035983.
# [I 2021-08-09 16:18:27,488] Trial 2 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:30,282] Trial 3 finished with value: 0.7817216512310077 and parameters: {'learning_rate': 0.6834629351721363, 'min_split_loss': 1.4254040539658004, 'max_depth': 38, 'min_child_weight': 5.611961860656249}. Best is trial 0 with value: 0.5872363030035983.
# [I 2021-08-09 16:18:34,804] Trial 4 finished with value: 0.6879324390640086 and parameters: {'learning_rate': 0.5030831653078097, 'min_split_loss': 0.027536899181364483, 'max_depth': 78, 'min_child_weight': 8.826411906361166}. Best is trial 0 with value: 0.5872363030035983.
# [I 2021-08-09 16:18:34,921] Trial 5 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:35,160] Trial 6 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:35,383] Trial 7 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:35,967] Trial 8 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:18:39,516] Trial 9 finished with value: 0.5781989998881406 and parameters: {'learning_rate': 0.21879210567408858, 'min_split_loss': 1.84973525723113, 'max_depth': 45, 'min_child_weight': 9.093159589724726}. Best is trial 9 with value: 0.5781989998881406.
# [I 2021-08-09 16:18:39,565] Trial 10 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:39,645] Trial 11 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:39,793] Trial 12 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:39,883] Trial 13 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:39,984] Trial 14 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:40,193] Trial 15 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:40,301] Trial 16 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:40,494] Trial 17 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:18:40,978] Trial 18 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:18:41,035] Trial 19 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:18:41,127] Trial 20 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:41,254] Trial 21 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:41,386] Trial 22 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:18:44,445] Trial 23 finished with value: 1.0156662927481914 and parameters: {'learning_rate': 0.7059975650817732, 'min_split_loss': 0.29966743197985446, 'max_depth': 75, 'min_child_weight': 8.310069924335378}. Best is trial 9 with value: 0.5781989998881406.
# [I 2021-08-09 16
pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:19:39,261] Trial 100 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:19:39,431] Trial 101 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:19:39,575] Trial 102 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:19:40,101] Trial 103 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:19:45,073] Trial 104 finished with value: 0.8682448896089672 and parameters: {'learning_rate': 0.00934857450024451, 'min_split_loss': 1.8012972423101838, 'max_depth': 98, 'min_child_weight': 5.568946791368349}. Best is trial 86 with value: 0.56235639648202.
# [I 2021-08-09 16:19:45,160] Trial 105 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:19:45,291] Trial 106 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:19:45,485] Trial 107 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:19:46,259] Trial 108 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:19:55,133] Trial 109 finished with value: 0.5827082435038509 and parameters: {'learning_rate': 0.08477384339419014, 'min_split_loss': 0.6660049314582002, 'max_depth': 73, 'min_child_weight': 1.4243537334181722}. Best is trial 86 with value: 0.56235639648202.
# [I 2021-08-09 16:19:55,304] Trial 110 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:19:55,943] Trial 111 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:19:56,018] Trial 112 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:19:56,549] Trial 113 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:00,744] Trial 114 finished with value: 0.7727635560339521 and parameters: {'learning_rate': 0.5524689394975455, 'min_split_loss': 0.5460865193673712, 'max_depth': 98, 'min_child_weight': 6.677869061450377}. Best is trial 86 with value: 0.56235639648202.
# [I 2021-08-09 16:20:01,345] Trial 115 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:01,855] Trial 116 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:06,989] Trial 117 finished with value: 0.5488514400962818 and parameters: {'learning_rate': 0.25565328643413965, 'min_split_loss': 0.21662298836545757, 'max_depth': 78, 'min_child_weight': 7.82477992600202}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:08,505] Trial 118 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:08,695] Trial 119 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:08,910] Trial 120 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:12,061] Trial 121 finished with value: 0.5667469688793769 and parameters: {'learning_rate': 0.2017556924529783, 'min_split_loss': 1.3965927511035223, 'max_depth': 96, 'min_child_weight': 8.899632871420051}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:16,445] Trial 122 finished with value: 1.0410247852290027 and parameters: {'learning_rate': 0.9935673628631737, 'min_split_loss': 1.637407020407851, 'max_depth': 55, 'min_child_weight': 4.512540549640983}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:17,080] Trial 123 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:17,200] Trial 124 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:17,354] Trial 125 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:19,698] Trial 126 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:20,240] Trial 127 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:20,454] Trial 128 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:20,781] Trial 129 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:21,139] Trial 130 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:21,306] Trial 131 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:21,475] Trial 132 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:21,644] Trial 133 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:21,869] Trial 134 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:21,996] Trial 135 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:22,640] Trial 136 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:23,345] Trial 137 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:23,471] Trial 138 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:23,614] Trial 139 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:23,740] Trial 140 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:25,447] Trial 141 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:26,180] Trial 142 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:26,690] Trial 143 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:27,237] Trial 144 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:28,828] Trial 145 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:29,195] Trial 146 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:29,744] Trial 147 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:29,958] Trial 148 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:30,151] Trial 149 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:30,275] Trial 150 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:30,424] Trial 151 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:30,704] Trial 152 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:30,840] Trial 153 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:31,526] Trial 154 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:31,659] Trial 155 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:31,868] Trial 156 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:32,043] Trial 157 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:32,126] Trial 158 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:32,196] Trial 159 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:32,308] Trial 160 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:32,449] Trial 161 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:32,580] Trial 162 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:32,722] Trial 163 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:32,847] Trial 164 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:33,090] Trial 165 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:33,245] Trial 166 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:33,377] Trial 167 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:33,474] Trial 168 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:33,565] Trial 169 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:36,399] Trial 170 finished with value: 0.5695695174597881 and parameters: {'learning_rate': 0.3230946929662495, 'min_split_loss': 1.742846510097396, 'max_depth': 22, 'min_child_weight': 7.3494518856219635}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:36,629] Trial 171 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:39,795] Trial 172 finished with value: 0.5719774246833462 and parameters: {'learning_rate': 0.3276410126311624, 'min_split_loss': 1.3252034621646438, 'max_depth': 71, 'min_child_weight': 9.405647947477716}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:40,300] Trial 173 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:40,417] Trial 174 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:40,627] Trial 175 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:40,838] Trial 176 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:40,961] Trial 177 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:42,385] Trial 178 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:42,521] Trial 179 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:42,688] Trial 180 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:44,267] Trial 181 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:44,903] Trial 182 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:20:46,772] Trial 183 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:47,052] Trial 184 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:47,206] Trial 185 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:51,784] Trial 186 finished with value: 0.6171534391584151 and parameters: {'learning_rate': 0.44390898141585244, 'min_split_loss': 0.062069722266665295, 'max_depth': 37, 'min_child_weight': 7.307217914103388}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:56,456] Trial 187 finished with value: 0.5911247604735232 and parameters: {'learning_rate': 0.3073031202777585, 'min_split_loss': 1.4877203849196472, 'max_depth': 55, 'min_child_weight': 3.2550522714739474}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:20:56,694] Trial 188 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:56,826] Trial 189 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:20:57,068] Trial 190 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:57,252] Trial 191 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:57,497] Trial 192 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:20:59,182] Trial 193 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:59,392] Trial 194 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:20:59,536] Trial 195 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:00,034] Trial 196 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:00,220] Trial 197 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:00,333] Trial 198 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:00,452] Trial 199 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:00,683] Trial 200 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:01,193] Trial 201 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:01,783] Trial 202 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:01,927] Trial 203 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:02,462] Trial 204 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:02,581] Trial 205 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:04,231] Trial 206 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:21:04,367] Trial 207 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:04,531] Trial 208 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:05,165] Trial 209 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:09,276] Trial 210 finished with value: 0.6716501361099756 and parameters: {'learning_rate': 0.5192481364852018, 'min_split_loss': 1.3343479355470445, 'max_depth': 100, 'min_child_weight': 5.079022391695623}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:09,797] Trial 211 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:09,991] Trial 212 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:10,201] Trial 213 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:13,648] Trial 214 finished with value: 0.6392548649860065 and parameters: {'learning_rate': 0.4477331585599427, 'min_split_loss': 0.8820743913470015, 'max_depth': 58, 'min_child_weight': 5.385431019053769}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:15,055] Trial 215 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:21:19,767] Trial 216 finished with value: 0.6738033687217981 and parameters: {'learning_rate': 0.5187817623486582, 'min_split_loss': 1.3380071280550472, 'max_depth': 94, 'min_child_weight': 5.034651829139626}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:19,902] Trial 217 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:23,600] Trial 218 finished with value: 0.7394774240430217 and parameters: {'learning_rate': 0.5059088152185263, 'min_split_loss': 1.312834671864713, 'max_depth': 94, 'min_child_weight': 4.369194417672282}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:23,798] Trial 219 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:23,919] Trial 220 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:24,426] Trial 221 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:28,673] Trial 222 finished with value: 0.7028273552894891 and parameters: {'learning_rate': 0.5054011441923434, 'min_split_loss': 1.143256438488599, 'max_depth': 95, 'min_child_weight': 5.047347218240154}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:29,266] Trial 223 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:32,864] Trial 224 finished with value: 0.6898834465035694 and parameters: {'learning_rate': 0.46377422164233634, 'min_split_loss': 1.2720313171576556, 'max_depth': 100, 'min_child_weight': 5.409862251302432}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:33,401] Trial 225 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:34,952] Trial 226 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:21:35,078] Trial 227 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:39,517] Trial 228 finished with value: 0.6252315216022498 and parameters: {'learning_rate': 0.3103592636363709, 'min_split_loss': 0.18284439804841254, 'max_depth': 56, 'min_child_weight': 5.51033704624024}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:40,024] Trial 229 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:45,721] Trial 230 finished with value: 0.6079416066326382 and parameters: {'learning_rate': 0.3113238004981419, 'min_split_loss': 0.1630650385942065, 'max_depth': 50, 'min_child_weight': 6.719733582358013}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:45,987] Trial 231 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:46,116] Trial 232 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:46,395] Trial 233 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:48,185] Trial 234 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:21:48,351] Trial 235 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:21:48,591] Trial 236 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:48,838] Trial 237 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:49,072] Trial 238 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:49,249] Trial 239 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:49,460] Trial 240 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:50,139] Trial 241 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:50,395] Trial 242 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:52,000] Trial 243 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:21:52,262] Trial 244 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:52,837] Trial 245 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:53,453] Trial 246 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:54,009] Trial 247 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:58,323] Trial 248 finished with value: 0.6893361642107688 and parameters: {'learning_rate': 0.4404074501791959, 'min_split_loss': 0.8725622367108177, 'max_depth': 49, 'min_child_weight': 4.164774462385373}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:21:58,944] Trial 249 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:21:59,220] Trial 250 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:21:59,570] Trial 251 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:22:00,274] Trial 252 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:22:00,559] Trial 253 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:22:02,201] Trial 254 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:22:02,663] Trial 255 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:22:07,419] Trial 256 finished with value: 0.6720704682187312 and parameters: {'learning_rate': 0.42858717826421844, 'min_split_loss': 1.688195809438411, 'max_depth': 87, 'min_child_weight': 4.339334338283274}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:07,604] Trial 257 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:22:07,826] Trial 258 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:22:08,146] Trial 259 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:22:08,485] Trial 260 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:22:08,824] Trial 261 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:22:13,103] Trial 262 finished with value: 0.6498679811830681 and parameters: {'learning_rate': 0.3918627949558396, 'min_split_loss': 1.9133529135094682, 'max_depth': 94, 'min_child_weight': 4.654837487224227}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:17,937] Trial 263 finished with value: 0.5944736777018983 and parameters: {'learning_rate': 0.3878716851948857, 'min_split_loss': 1.9341410140389461, 'max_depth': 95, 'min_child_weight': 4.81285516957378}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:22,662] Trial 264 finished with value: 0.6092154889665606 and parameters: {'learning_rate': 0.41814554232298784, 'min_split_loss': 1.941046183634943, 'max_depth': 95, 'min_child_weight': 4.5163967712066295}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:22,806] Trial 265 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:22:22,995] Trial 266 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:22:28,893] Trial 267 finished with value: 0.5964714453905596 and parameters: {'learning_rate': 0.4072091925202598, 'min_split_loss': 1.9052267911727645, 'max_depth': 95, 'min_child_weight': 4.243692966775755}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:33,303] Trial 268 finished with value: 0.6195832236447884 and parameters: {'learning_rate': 0.384597547328579, 'min_split_loss': 1.8952694787427462, 'max_depth': 93, 'min_child_weight': 4.16841971324854}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:38,123] Trial 269 finished with value: 0.7152377523798461 and parameters: {'learning_rate': 0.4755665730836416, 'min_split_loss': 0.6888339402440053, 'max_depth': 65, 'min_child_weight': 1.2620532161439946}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:38,253] Trial 270 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:22:39,906] Trial 271 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:22:41,392] Trial 272 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:22:46,080] Trial 273 finished with value: 0.6404417566058662 and parameters: {'learning_rate': 0.39437408922714995, 'min_split_loss': 0.41948065063765444, 'max_depth': 73, 'min_child_weight': 4.841842685640021}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:49,285] Trial 274 finished with value: 0.7770760319016148 and parameters: {'learning_rate': 0.3686767048498175, 'min_split_loss': 1.826088941066326, 'max_depth': 100, 'min_child_weight': 4.369458784828097}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:22:49,811] Trial 275 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:22:50,315] Trial 276 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:22:51,693] Trial 277 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:22:56,205] Trial 278 finished with value: 0.6083801706373695 and parameters: {'learning_rate': 0.3790012928244752, 'min_split_loss': 1.794312161009599, 'max_depth': 100, 'min_child_weight': 4.332402398866335}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16
pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:23:56,980] Trial 344 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:23:59,701] Trial 345 finished with value: 0.5950150183787327 and parameters: {'learning_rate': 0.17146526096424974, 'min_split_loss': 1.4741729873770433, 'max_depth': 13, 'min_child_weight': 3.696498749466268}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:02,812] Trial 346 finished with value: 0.632706953273911 and parameters: {'learning_rate': 0.43867264375314596, 'min_split_loss': 1.9315225163321792, 'max_depth': 74, 'min_child_weight': 5.330433065215152}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:06,325] Trial 347 finished with value: 0.6514988458699121 and parameters: {'learning_rate': 0.4433378904636211, 'min_split_loss': 1.9972334233793103, 'max_depth': 71, 'min_child_weight': 5.263673388064753}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:06,837] Trial 348 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:06,991] Trial 349 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:08,506] Trial 350 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:14,273] Trial 351 finished with value: 0.5572835284438451 and parameters: {'learning_rate': 0.18605546087714026, 'min_split_loss': 0.027940726336918464, 'max_depth': 50, 'min_child_weight': 7.717676239262559}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:17,845] Trial 352 finished with value: 0.6737564509351399 and parameters: {'learning_rate': 0.4500209783920203, 'min_split_loss': 1.9998613016724007, 'max_depth': 75, 'min_child_weight': 5.294085560929668}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:18,064] Trial 353 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:18,190] Trial 354 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:24:18,709] Trial 355 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:20,264] Trial 356 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:20,467] Trial 357 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:20,675] Trial 358 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:21,205] Trial 359 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:21,544] Trial 360 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:22,029] Trial 361 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:22,238] Trial 362 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:22,381] Trial 363 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:24:22,509] Trial 364 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:24,206] Trial 365 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:24,461] Trial 366 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:24,919] Trial 367 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:26,515] Trial 368 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:26,642] Trial 369 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:24:26,860] Trial 370 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:27,052] Trial 371 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:30,805] Trial 372 finished with value: 0.6619772702953409 and parameters: {'learning_rate': 0.44789964342392136, 'min_split_loss': 1.8751541893247092, 'max_depth': 95, 'min_child_weight': 5.587786628027452}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:31,316] Trial 373 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:24:32,765] Trial 374 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:32,963] Trial 375 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:33,177] Trial 376 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:36,892] Trial 377 finished with value: 0.6381042733191185 and parameters: {'learning_rate': 0.43113374330936577, 'min_split_loss': 1.9989947501272374, 'max_depth': 98, 'min_child_weight': 5.196830763026972}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:40,335] Trial 378 finished with value: 0.6378854687063827 and parameters: {'learning_rate': 0.43167778886925623, 'min_split_loss': 1.9984146513076204, 'max_depth': 97, 'min_child_weight': 5.630716242988676}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:44,074] Trial 379 finished with value: 0.6378732857624725 and parameters: {'learning_rate': 0.43164232688381066, 'min_split_loss': 1.9984343633635344, 'max_depth': 97, 'min_child_weight': 5.5497132329506815}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:44,328] Trial 380 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:48,778] Trial 381 finished with value: 0.6563229602886314 and parameters: {'learning_rate': 0.6043340048360264, 'min_split_loss': 0.20620887771129448, 'max_depth': 81, 'min_child_weight': 9.455532358421245}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:50,412] Trial 382 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:51,386] Trial 383 finished with value: 0.7464832236505382 and parameters: {'learning_rate': 0.04032494712856266, 'min_split_loss': 0.08375991050473204, 'max_depth': 3, 'min_child_weight': 8.063103889715407}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:51,577] Trial 384 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:54,665] Trial 385 finished with value: 0.6134551902078582 and parameters: {'learning_rate': 0.2587858537144443, 'min_split_loss': 1.9293441825302922, 'max_depth': 98, 'min_child_weight': 9.006205374040338}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:24:56,029] Trial 386 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:56,233] Trial 387 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:58,025] Trial 388 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:24:58,224] Trial 389 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:58,387] Trial 390 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:24:59,896] Trial 391 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:00,013] Trial 392 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:00,515] Trial 393 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:01,094] Trial 394 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:01,215] Trial 395 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:01,359] Trial 396 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:01,850] Trial 397 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:03,423] Trial 398 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:03,808] Trial 399 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:04,125] Trial 400 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:04,293] Trial 401 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:04,860] Trial 402 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:06,370] Trial 403 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:06,901] Trial 404 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:08,388] Trial 405 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:08,934] Trial 406 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:09,062] Trial 407 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:09,224] Trial 408 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:13,317] Trial 409 finished with value: 0.5993888077112651 and parameters: {'learning_rate': 0.3889786160165902, 'min_split_loss': 1.9604008184585446, 'max_depth': 98, 'min_child_weight': 5.115198728180123}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:25:13,520] Trial 410 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:13,751] Trial 411 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:15,314] Trial 412 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:15,833] Trial 413 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:16,056] Trial 414 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:19,961] Trial 415 finished with value: 0.5864657517449817 and parameters: {'learning_rate': 0.40570541562920215, 'min_split_loss': 1.9334087474881803, 'max_depth': 94, 'min_child_weight': 5.265746529870947}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:25:22,974] Trial 416 pruned. Trial was pruned at iteration 81.
# [I 2021-08-09 16:25:23,181] Trial 417 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:27,613] Trial 418 pruned. Trial was pruned at iteration 81.
# [I 2021-08-09 16:25:27,824] Trial 419 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:28,037] Trial 420 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:28,559] Trial 421 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:28,724] Trial 422 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:28,906] Trial 423 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:29,555] Trial 424 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:30,014] Trial 425 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:30,140] Trial 426 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:30,384] Trial 427 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:30,928] Trial 428 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:35,555] Trial 429 finished with value: 0.6001730147510261 and parameters: {'learning_rate': 0.393203185099042, 'min_split_loss': 1.943129776455052, 'max_depth': 95, 'min_child_weight': 5.269571249538953}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:25:36,065] Trial 430 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:36,255] Trial 431 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:36,476] Trial 432 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:36,998] Trial 433 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:38,622] Trial 434 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:38,942] Trial 435 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:39,516] Trial 436 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:40,108] Trial 437 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:41,634] Trial 438 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:45,055] Trial 439 finished with value: 0.6774225960130408 and parameters: {'learning_rate': 0.4119706504688663, 'min_split_loss': 1.9631762215628368, 'max_depth': 95, 'min_child_weight': 4.707010842401051}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:25:45,659] Trial 440 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:50,591] Trial 441 finished with value: 0.6179605195089736 and parameters: {'learning_rate': 0.416038078977606, 'min_split_loss': 0.8141861889530417, 'max_depth': 70, 'min_child_weight': 5.060166910570135}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:25:51,139] Trial 442 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:51,405] Trial 443 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:55,843] Trial 444 finished with value: 0.5883956164747801 and parameters: {'learning_rate': 0.13270678499802174, 'min_split_loss': 1.999297247674805, 'max_depth': 67, 'min_child_weight': 3.338747421920771}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:25:55,975] Trial 445 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:25:57,717] Trial 446 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:25:57,955] Trial 447 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:25:58,515] Trial 448 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:25:58,725] Trial 449 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:00,303] Trial 450 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:01,864] Trial 451 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:02,421] Trial 452 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:02,653] Trial 453 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:06,064] Trial 454 finished with value: 0.6430000091317974 and parameters: {'learning_rate': 0.38191374216659557, 'min_split_loss': 0.865610534006205, 'max_depth': 49, 'min_child_weight': 7.111151404235073}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:06,857] Trial 455 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:06,990] Trial 456 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:07,555] Trial 457 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:09,634] Trial 458 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:11,247] Trial 459 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:11,527] Trial 460 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:11,669] Trial 461 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:11,820] Trial 462 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:12,041] Trial 463 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:12,287] Trial 464 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:12,430] Trial 465 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:12,960] Trial 466 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:13,436] Trial 467 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:16,770] Trial 468 finished with value: 0.6678555254023103 and parameters: {'learning_rate': 0.5316712016373596, 'min_split_loss': 0.7152958076081375, 'max_depth': 75, 'min_child_weight': 8.380514105568922}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:21,451] Trial 469 finished with value: 0.6145571153211921 and parameters: {'learning_rate': 0.3778611620314918, 'min_split_loss': 0.26906832485378007, 'max_depth': 32, 'min_child_weight': 5.530596269264945}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:26,207] Trial 470 finished with value: 0.6451037187524693 and parameters: {'learning_rate': 0.5305877086997289, 'min_split_loss': 0.7128781999048862, 'max_depth': 74, 'min_child_weight': 8.495837197598503}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:30,597] Trial 471 finished with value: 0.6238136773541537 and parameters: {'learning_rate': 0.3948643330022338, 'min_split_loss': 0.16746642692462949, 'max_depth': 32, 'min_child_weight': 5.464354648009992}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:30,731] Trial 472 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:35,452] Trial 473 finished with value: 0.5916996703491472 and parameters: {'learning_rate': 0.36627131472270974, 'min_split_loss': 1.9983391371699675, 'max_depth': 100, 'min_child_weight': 4.321476419608656}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:35,965] Trial 474 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:36,182] Trial 475 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:36,352] Trial 476 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:36,580] Trial 477 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:37,155] Trial 478 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:42,856] Trial 479 finished with value: 0.604009407703852 and parameters: {'learning_rate': 0.17259195075680003, 'min_split_loss': 0.00636891673823161, 'max_depth': 51, 'min_child_weight': 4.27639931574329}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:43,416] Trial 480 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:43,986] Trial 481 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:44,171] Trial 482 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:44,729] Trial 483 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:47,649] Trial 484 pruned. Trial was pruned at iteration 81.
# [I 2021-08-09 16:26:49,836] Trial 485 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:54,680] Trial 486 finished with value: 0.6007919799632152 and parameters: {'learning_rate': 0.31905828594182944, 'min_split_loss': 0.17682575881937046, 'max_depth': 37, 'min_child_weight': 5.646165030082221}. Best is trial 117 with value: 0.5488514400962818.
# [I 2021-08-09 16:26:54,814] Trial 487 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:54,995] Trial 488 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:55,202] Trial 489 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:55,350] Trial 490 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:55,860] Trial 491 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:55,993] Trial 492 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:57,074] Trial 493 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:57,270] Trial 494 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:58,872] Trial 495 pruned. Trial was pruned at iteration 27.
# [I 2021-08-09 16:26:59,025] Trial 496 pruned. Trial was pruned at iteration 1.
# [I 2021-08-09 16:26:59,277] Trial 497 pruned. Trial was pruned at iteration 3.
# [I 2021-08-09 16:26:59,727] Trial 498 pruned. Trial was pruned at iteration 9.
# [I 2021-08-09 16:26:59,869] Trial 499 pruned. Trial was pruned at iteration 1.
# /Users/mat3ra/sisso_collab/.env/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# # Regression - Results
#
# Overall, we see okay performance of the model. Certainly not the big gains in performance that we had hoped for when removing the metals from the dataset.
#
# One thing we could try to improve our predictions here would be to manually remove all metals from the training set, then train on those. This would likely lead to even worse performance in the case of the metal systems that had been misclassified as nonmetals - but those are already wrong by quite a lot anyway.
#
# Below, we output the test-set error metrics, since those are the ones that really tell us if our model will generalize. Reproduced here:
#
# | Error Metric | Test-Set Value    |
# |--------------|-------------------|
# | MAE          | 0.67              |
# | MSE          | 0.825             |
# | RMSE         | 0.909             |
# | MAPE         | 543850845913702.8 |
# | R2           | 0.703             |
#
# - The MAE is comparable to a related model, MegNet [Link](https://github.com/materialsvirtuallab/megnet). MegNet is a graph convolution neural network trained on a variety of different datasets. When compared with DFT bandgaps from Materials Project (slightly different, as that dataset is of 3D materials and not 2D materials), they report a MAE of 0.33 eV for the bandgap. Considering we're not training a neural network on huge numbers of samples, this should put our MAE of 0.67 eV in perspective.
# - We see a similar story for our RMSE (square root of our MSE), which is 0.909 eV.
# - The Mean Absolute Percent Error (MAPE) is high, but this is because we have 0-valued entries in the dataset - this is why this metric is generally avoided in the case of data with 0s in their values (it also tends to cause models to underestinate when used as a loss function, which is another reason we don't use it as our loss function).
# - Finally, we see that our R2 is 0.703, so our test set predictions are at least correlated with our dataset.

# %%
def rmse(y_true, y_pred):
    mse = sklearn.metrics.mean_squared_error(y_true=y_true, y_pred=y_pred)
    rmse = np.sqrt(abs(mse))
    return rmse

metrics = {
    'MaxError': sklearn.metrics.max_error,
    'MAE': sklearn.metrics.mean_absolute_error,
    'MSE': sklearn.metrics.mean_squared_error,
    'RMSE': rmse,
    'MAPE': sklearn.metrics.mean_absolute_percentage_error,
    'R2': sklearn.metrics.r2_score
}

y_pred_test = best_reg.predict(test_x_reg)
for key, fun in metrics.items():
    value = fun(y_true=test_y_reg, y_pred=y_pred_test)
    print(key,np.round(value,3))
# Out:
# MaxError 4.074
# MAE 0.67
# MSE 0.825
# RMSE 0.909
# MAPE 543850845913702.8
# R2 0.703

# %% [markdown]
# # Regression - Feature Importances
#
# Finally, in the below plot we will list the feature importances of our XGBoost model. Here are a few of the most-important features:
# 1. `min:GS_Energy` is a property from XenonPy. It is derived by looking at the ground-state electronic energy of the bulk cells of each element in the system (e.g. a system containing NaCl would look at the bulk cell for Na and the bulk cell for Cl). The `min` in front tells us that this version of the feature chooses the minimum amongst the ground-state DFT energies in each elemental system.
# 2. `var:VDW_radius_MM3` is another XenonPy property. As is the case with all the Xenonpy descriptors we use in this notebook, it is derived by looking at tabulated values for each element in the system. In this case, we take the variance of the elemntal VDW radii, as tabulated by the MM3 forcefield.
# 3. `ave:density` is yet another XenonPy descriptor, and is the average of the elemental densities in their respective bulk cells.

# %%
n_importances = 20
importances = list(zip(best_reg[1].feature_importances_, xenonpy_matminer_descriptors))

sorted_importances = list(sorted(importances, key=lambda i: -i[0]))



plt.barh(range(n_importances), [imp[0] for imp in sorted_importances[:n_importances]])
plt.yticks(range(n_importances), [imp[1] for imp in sorted_importances[:n_importances]])
plt.ylabel("Feature")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.savefig("Importances.jpeg")

# %% [markdown]
# # Conclusions
#
# Overall, in this notebook we:
#
# 1. Trained a classifier to predict whether a material is likely to be a metal or a nonmetal, with very good performance.
# 2. Identified that our data seems to be Tweedie-Distributed once we remove the nonmetals - which might be contributing to some of the error in the model (the high density of points at 0 eV).
# 3. Trained a regression model to predict the bandgap, with MAE comparable to a graph convolutional neural network that had been trained to address the bandgap of similar materials.
# 4. Identified several features important to the prediction of the bandgap, as determined by the importance score of our XGBoost model.

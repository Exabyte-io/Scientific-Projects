# %% [markdown]
# # Exfoliation Energy
#
# In this notebook, we train an XGBoost regressor to predict exfoliation energies.

# %%
import copy

import pandas as pd
import numpy as np
import optuna
import xgboost
import imblearn.over_sampling
import sklearn.model_selection
import dscribe.descriptors
import tqdm
import sklearn.pipeline

import functools

import matplotlib.pyplot as plt
import sklearn.impute
import seaborn as sns

import sys
sys.path.append("../../../")
import DigitalEcosystem.utils.figures
from DigitalEcosystem.utils.misc import matminer_descriptors
from DigitalEcosystem.utils.element_symbols import noble_gases, f_block_elements, synthetic_elements_in_d_block

tqdm.tqdm.pandas()

# %%
# Random seeds for reproducibility
RANDOM_SEED = 1234
import random
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # Read in the Dataset

# %%
# Load up the data
data_path = "../../refined/httpot/full_featurized_data.pkl"
data = pd.read_pickle(data_path).fillna(0)

# %% [markdown]
# # Filter out by several masks
#
# - `element_mask` - throw away systems containing noble gases, f-blocks, or any synthetic elements
# - `decomposition_mask` - keep systems with a decomposition energy < 0.5 eV/atom
# - `exfol_mask` - keep systems with an exfoliation energy > 0 eV/atom
#
# And finally, do a train/test split

# %%
bad_elements = noble_gases + f_block_elements + synthetic_elements_in_d_block

element_mask = data['atoms_object (unitless)'].apply(lambda atoms: all([forbidden not in atoms.get_chemical_symbols() for forbidden in bad_elements]))

decomposition_mask = data['decomposition_energy (eV/atom)'] < 0.5

reasonable = data[element_mask & decomposition_mask]

# %%
target_column = ['exfoliation_energy_per_atom (eV/atom)']

# %%
reasonable = reasonable[reasonable['exfoliation_energy_per_atom (eV/atom)'] > 0]

# %%
train, test = sklearn.model_selection.train_test_split(reasonable, test_size=0.1, random_state=RANDOM_SEED)

# %% [markdown]
# # Descriptor selection
#
# XenonPy and Matminer

# %%
xenonpy_descriptors = [col for col in data.columns if ":" in col]
xenonpy_matminer_descriptors = xenonpy_descriptors + matminer_descriptors + ['decomposition_energy (eV/atom)', 'bandgap (eV)']

# %%
train_x_regression = np.nan_to_num(train[xenonpy_matminer_descriptors].to_numpy())
train_y_regression = np.nan_to_num(train[target_column].to_numpy())

test_x_regression = np.nan_to_num(test[xenonpy_matminer_descriptors].to_numpy())
test_y_regression = np.nan_to_num(test[target_column].to_numpy())

# %% [markdown]
# # XGBoost Hyperparameter Tuning
#
# Tune an XGBoost regressor for the exfoliation energy using Optuna.

# %%
current_regression = None
best_regression = None
def keep_best_regression(study, trial):
    global best_regression
    if study.best_trial == trial:
        best_regression = current_regression

objective_train_x_regression, objective_validation_x_regression, objective_train_y_regression, objective_validation_y_regression = sklearn.model_selection.train_test_split(
    np.nan_to_num(train_x_regression), train_y_regression, test_size=0.1, random_state=RANDOM_SEED)

def objective(trial: optuna.Trial):
    global current_regression

    current_regression = sklearn.pipeline.Pipeline([
        ("Scaler", sklearn.preprocessing.MinMaxScaler()),
        ("XGB_Regressor", xgboost.sklearn.XGBRegressor(
            max_depth= trial.suggest_int('max_depth', 1, 100),
            min_child_weight= trial.suggest_float('min_child_weight', 0, 10),
            reg_alpha = trial.suggest_float('alpha', 0, 5),
            reg_lambda = trial.suggest_float('lambda', 0, 5),
            n_estimators=200,
            objective='reg:squarederror',
            random_state=RANDOM_SEED),),
    ])

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'validation_0-rmse')
    current_regression.fit(X=objective_train_x_regression, y=objective_train_y_regression,
                         **{
                            'XGB_Regressor__eval_set': [[objective_validation_x_regression, objective_validation_y_regression]],
                            'XGB_Regressor__eval_metric': 'rmse',
                            'XGB_Regressor__early_stopping_rounds': 10,
                            'XGB_Regressor__callbacks': [pruning_callback],
                            'XGB_Regressor__verbose': False
                         })

    score = sklearn.metrics.mean_squared_error(
        y_true=objective_validation_y_regression,
        y_pred=abs(current_regression.predict(objective_validation_x_regression)),
    )

    return np.sqrt(score)

regression_study = optuna.create_study(
    sampler = optuna.samplers.TPESampler(
        seed = RANDOM_SEED,
        warn_independent_sampling = True,
        consider_endpoints = True
    ),
    pruner = optuna.pruners.HyperbandPruner(
        min_resource=1,
        max_resource=100),
    direction='minimize'
)

regression_study.optimize(func=objective, n_trials=256, callbacks=[keep_best_regression])
# Out:
# [I 2021-09-22 14:48:14,596] A new study created in memory with name: no-name-9545ac81-0786-474c-87da-734c491c2701
# [I 2021-09-22 14:48:15,008] Trial 0 finished with value: 0.12203334356466433 and parameters: {'max_depth': 20, 'min_child_weight': 6.221087710398319, 'alpha': 2.1886386950355723, 'lambda': 3.926792918568846}. Best is trial 0 with value: 0.12203334356466433.
# [I 2021-09-22 14:48:15,099] Trial 1 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:15,776] Trial 2 finished with value: 0.06749510231988913 and parameters: {'max_depth': 96, 'min_child_weight': 8.759326347420947, 'alpha': 1.7890863497893332, 'lambda': 2.5049756276172936}. Best is trial 2 with value: 0.06749510231988913.
# [I 2021-09-22 14:48:15,850] Trial 3 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:15,910] Trial 4 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:16,667] Trial 5 finished with value: 0.06046203073276117 and parameters: {'max_depth': 37, 'min_child_weight': 6.153961784334937, 'alpha': 0.37690620821488274, 'lambda': 1.8441200300098726}. Best is trial 5 with value: 0.06046203073276117.
# [I 2021-09-22 14:48:16,713] Trial 6 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:16,760] Trial 7 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:17,340] Trial 8 finished with value: 0.15461063612228065 and parameters: {'max_depth': 81, 'min_child_weight': 1.4376682451456457, 'alpha': 3.5213048555916773, 'lambda': 3.522906540947863}. Best is trial 5 with value: 0.06046203073276117.
# [I 2021-09-22 14:48:17,418] Trial 9 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:17,503] Trial 10 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:17,590] Trial 11 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:17,667] Trial 12 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:17,816] Trial 13 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:17,886] Trial 14 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:18,329] Trial 15 finished with value: 0.1219605170718585 and parameters: {'max_depth': 29, 'min_child_weight': 6.249167053059111, 'alpha': 2.390468978353373, 'lambda': 0.9783758933294912}. Best is trial 5 with value: 0.06046203073276117.
# [I 2021-09-22 14:48:18,473] Trial 16 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:18,584] Trial 17 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:18,641] Trial 18 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:18,703] Trial 19 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:18,782] Trial 20 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:18,834] Trial 21 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:18,888] Trial 22 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:18,953] Trial 23 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:19,012] Trial 24 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:19,132] Trial 25 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:19,238] Trial 26 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48:19,296] Trial 27 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:19,352] Trial 28 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:48:19,477] Trial 29 finished with value: 0.08505631208015905 and parameters: {'max_depth': 1, 'min_child_weight': 3.951611552011053, 'alpha': 0.8140959313635368, 'lambda': 2.4075694299984827}. Best is trial 5 with value: 0.06046203073276117.
# [I 2021-09-22 14:48:19,562] Trial 30 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:48
pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:49:11,756] Trial 240 finished with value: 0.07024540378956552 and parameters: {'max_depth': 3, 'min_child_weight': 4.672474270955337, 'alpha': 0.12819084888306065, 'lambda': 0.48450484877306144}. Best is trial 162 with value: 0.05658489982678908.
# [I 2021-09-22 14:49:12,165] Trial 241 pruned. Trial was pruned at iteration 9.
# [I 2021-09-22 14:49:12,253] Trial 242 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:49:13,194] Trial 243 finished with value: 0.06312277295171263 and parameters: {'max_depth': 98, 'min_child_weight': 7.984001350778232, 'alpha': 0.05238919435045754, 'lambda': 4.826243728927596}. Best is trial 162 with value: 0.05658489982678908.
# [I 2021-09-22 14:49:13,253] Trial 244 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:49:13,432] Trial 245 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:49:14,176] Trial 246 finished with value: 0.20785898400932115 and parameters: {'max_depth': 45, 'min_child_weight': 0.3103486113333265, 'alpha': 1.8161988009679901, 'lambda': 3.653608957051694}. Best is trial 162 with value: 0.05658489982678908.
# [I 2021-09-22 14:49:14,438] Trial 247 finished with value: 0.06571959869953121 and parameters: {'max_depth': 3, 'min_child_weight': 6.603989020939084, 'alpha': 1.18055924596891, 'lambda': 2.1256567777686257}. Best is trial 162 with value: 0.05658489982678908.
# [I 2021-09-22 14:49:14,663] Trial 248 pruned. Trial was pruned at iteration 9.
# [I 2021-09-22 14:49:14,772] Trial 249 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:49:15,130] Trial 250 pruned. Trial was pruned at iteration 9.
# [I 2021-09-22 14:49:15,323] Trial 251 finished with value: 0.07304816040910306 and parameters: {'max_depth': 2, 'min_child_weight': 7.001294498523489, 'alpha': 1.368806882516498, 'lambda': 2.0903137328439065}. Best is trial 162 with value: 0.05658489982678908.
# [I 2021-09-22 14:49:15,418] Trial 252 pruned. Trial was pruned at iteration 1.
# [I 2021-09-22 14:49:15,509] Trial 253 pruned. Trial was pruned at iteration 3.
# [I 2021-09-22 14:49:15,871] Trial 254 pruned. Trial was pruned at iteration 9.
# [I 2021-09-22 14:49:15,950] Trial 255 pruned. Trial was pruned at iteration 1.

# %% [markdown]
# # Save summary statistics
#
# - A parity plot for the model and the entire data range
# - A bar chart for some of the variable importances
# - Model performance statistics are also printed

# %%
DigitalEcosystem.utils.figures.save_parity_plot(train_x_regression,
                                                test_x_regression,
                                                train_y_regression,
                                                test_y_regression,
                                                best_regression,
                                                "Exfoliation Energy (eV/atom)",
                                                "exfoliation_parity.jpeg")

# %%
def rmse(y_true, y_pred):
    mse = sklearn.metrics.mean_squared_error(y_true=y_true, y_pred=y_pred)
    rmse = np.sqrt(abs(mse))
    return rmse

metrics = {
    'MaxError': sklearn.metrics.max_error,
    'MAE': sklearn.metrics.mean_absolute_error,
    'MSE': sklearn.metrics.mean_squared_error,
    'RMSE': rmse,
    'MAPE': sklearn.metrics.mean_absolute_percentage_error,
    'R2': sklearn.metrics.r2_score
}

y_pred_test = best_regression.predict(test_x_regression)
for key, fun in metrics.items():
    value = fun(y_true=test_y_regression, y_pred=y_pred_test)
    print(key,np.round(value,3))
# Out:
# MaxError 0.309
# MAE 0.04
# MSE 0.004
# RMSE 0.063
# MAPE 3.211
# R2 0.649

# %%
n_importances = 20
importances = list(zip(best_regression[1].feature_importances_, xenonpy_matminer_descriptors))

sorted_importances = list(sorted(importances, key=lambda i: -i[0]))



plt.barh(range(n_importances), [imp[0] for imp in sorted_importances[:n_importances]])
plt.yticks(range(n_importances), [imp[1] for imp in sorted_importances[:n_importances]])
plt.ylabel("Feature")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.savefig("importances_exfoliation.jpeg")

# %%
sns.histplot(reasonable['exfoliation_energy_per_atom (eV/atom)'])
# Out:
# <AxesSubplot:xlabel='exfoliation_energy_per_atom (eV/atom)', ylabel='Count'>

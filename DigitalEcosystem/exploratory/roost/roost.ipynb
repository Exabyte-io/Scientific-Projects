# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
bandgap_train = pd.read_csv('bandgap_preds_train.csv')
bandgap_test = pd.read_csv('bandgap_preds_test.csv')
exfoliation_train = pd.read_csv('exfol_preds_train.csv')
exfoliation_test = pd.read_csv('exfol_preds_test.csv')

# %%
bandgap_train
# Out:
#      material_id composition  bandgap_pred_n0  bandgap_target
# 0       2dm-4928        SeZn         0.155244          2.1824
# 1       2dm-5106        AgCl         0.152424          0.9837
# 2        2dm-859        F2Hf         0.268592          1.4086
# 3        2dm-439       AsCl3         2.633516          3.7066
# 4       2dm-5195   Be2Cl6Te7         1.465307          1.3979
# ...          ...         ...              ...             ...
# 3044    2dm-5781        STl2         1.038102          1.4621
# 3045    2dm-5508      CBi2O5         1.204952          0.0000
# 3046    2dm-2480        ClK2         0.141138          0.0000
# 3047    2dm-1358       Cu2Te         0.143180          0.0382
# 3048    2dm-5114     Ag2O2Pd         0.144332          0.3942
#
# [3049 rows x 4 columns]

# %%
plt.rcParams['figure.figsize'] = [10,10]
plt.rcParams['font.size'] = 16
plt.scatter(x=bandgap_train['bandgap_target'], y=bandgap_train['bandgap_pred_n0'], label='Training Set')
plt.scatter(x=bandgap_test['bandgap_target'], y=bandgap_test['bandgap_pred_n0'], label='Testing Set')
plt.plot([0,9],[0,9], c='k', label='Parity')
plt.xlim([0,9])
plt.ylim([0,9])
plt.legend()
plt.xlabel('DFT Bandgap (eV)')
plt.ylabel('Predicted Bandgap (eV)')
# Out:
# Text(0, 0.5, 'Predicted Bandgap (eV)')

# %%
plt.rcParams['figure.figsize'] = [10,10]
plt.rcParams['font.size'] = 16
plt.scatter(x=exfoliation_train['exfoliation_energy_target'], y=exfoliation_train['exfoliation_energy_pred_n0'], label='Training Set')
plt.scatter(x=exfoliation_test['exfoliation_energy_target'], y=exfoliation_test['exfoliation_energy_pred_n0'], label='Testing Set')
plt.plot([0,10],[0,10], c='k', label='Parity')
plt.xlim([0,10])
plt.ylim([0,10])
plt.legend()
plt.xlabel('DFT Exfoliation Energy (eV)')
plt.ylabel('Predicted Exfoliation Energy (eV)')
# Out:
# Text(0, 0.5, 'Predicted Exfoliation Energy (eV)')

# %%
exfoliation_train
# Out:
#      material_id composition  exfoliation_energy_pred_n0  \
# 0       2dm-4928        SeZn                    0.385073
# 1       2dm-5106        AgCl                    0.468172
# 2        2dm-859        F2Hf                    0.317933
# 3        2dm-439       AsCl3                    0.285552
# 4       2dm-5195   Be2Cl6Te7                    0.323787
# ...          ...         ...                         ...
# 3044    2dm-5781        STl2                    0.395445
# 3045    2dm-5508      CBi2O5                    1.530107
# 3046    2dm-2480        ClK2                    0.499268
# 3047    2dm-1358       Cu2Te                    0.401037
# 3048    2dm-5114     Ag2O2Pd                    0.724211
#
#       exfoliation_energy_target
# 0                      0.325015
# 1                      0.589342
# 2                      0.654208
# 3                      0.197714
# 4                      0.408292
# ...                         ...
# 3044                   0.361855
# 3045                   1.814497
# 3046                   0.460399
# 3047                   0.405294
# 3048                   1.023031
#
# [3049 rows x 4 columns]

# %%
import pandas as pd

# %%
import math
import random
import numpy as np
import sklearn
import sklearn.ensemble
import pandas as pd
import matplotlib.pyplot as plt
import tpot

# %%
data = pd.read_pickle("../raw_data/2d_mat_dataset_raw.pkl")
data = data.drop(columns=["2dm_id (unitless)", "formula", "atoms_object (unitless)", "potcars (unitless)", "is_hubbard (unitless)", "is_bandgap_direct (unitless)", "energy_per_atom (eV)", "is_metal (unitless)",
                          "decomposition_energy (eV/atom)"]).dropna().drop(columns=["discovery_process (unitless)"])
#data = data[data["discovery_process (unitless)"] == "top-down"].drop(columns=["discovery_process (unitless)"])
data
# Out:
#       exfoliation_energy_per_atom (eV/atom)  energy_vdw_per_atom (eV/atom)  \
# 0                                  0.234617                      -3.361686
# 1                                  0.210645                      -2.186996
# 2                                  0.095794                      -2.231434
# 3                                 -0.055818                      -4.469708
# 5                                  0.084831                      -3.107710
# ...                                     ...                            ...
# 5976                               0.059848                      -4.146506
# 6347                               0.113072                      -4.245431
# 6348                               0.125031                      -3.856898
# 6349                               0.108621                      -4.459145
# 6350                               0.126989                      -4.054575
#
#       total_magnetization (Bohr Magneton)  bandgap (eV)  ave:atomic_number  \
# 0                            2.487400e-01        0.0000          31.666667
# 1                            7.488541e-01        0.0000          54.333333
# 2                           -0.000000e+00        0.9814          48.500000
# 3                            0.000000e+00        0.0000          25.333333
# 5                            0.000000e+00        1.1619          50.000000
# ...                                   ...           ...                ...
# 5976                         6.423405e+00        0.0000          35.666667
# 6347                         1.500000e-05        0.0000          47.000000
# 6348                         2.000000e-07        0.0000          56.000000
# 6349                         2.050000e-05        0.0000          47.000000
# 6350                         2.400000e-06        0.0000          56.000000
#
#       ave:atomic_radius  ave:atomic_radius_rahm  ave:atomic_volume  \
# 0            134.682409              186.333333          14.246667
# 1            201.000000              277.333333          32.133333
# 2            149.000000              228.000000          16.350000
# 3            144.569212              218.666667          15.600000
# 5            145.159728              237.666667          19.900000
# ...                 ...                     ...                ...
# 5976         139.166667              232.666667          12.650000
# 6347         133.000000              222.000000          12.300000
# 6348         139.500000              227.000000          12.800000
# 6349         133.000000              222.000000          12.300000
# 6350         139.500000              227.000000          12.800000
#
#       ave:atomic_weight  ave:boiling_point  ...  min:num_s_valence  \
# 0             76.737935        1524.340000  ...                2.0
# 1            132.138000        1909.333333  ...                2.0
# 2            118.220000        1223.912000  ...                2.0
# 3             55.616667        1787.400000  ...                1.0
# 5            118.292980        1696.000000  ...                1.0
# ...                 ...                ...  ...                ...
# 5976          82.560833        2449.666667  ...                2.0
# 6347         113.572000        2408.912000  ...                1.0
# 6348         137.027500        2529.050000  ...                1.0
# 6349         113.572000        2408.912000  ...                1.0
# 6350         137.027500        2529.050000  ...                1.0
#
#       min:period  min:specific_heat  min:thermal_conductivity  min:vdw_radius  \
# 0            2.0              0.133                    0.0277           147.0
# 1            5.0              0.192                   18.0000           206.0
# 2            3.0              0.128                    0.2050           180.0
# 3            3.0              0.251                    0.0089           175.0
# 5            5.0              0.238                    0.4490           198.0
# ...          ...                ...                       ...             ...
# 5976         4.0              0.201                    3.0000           204.0
# 6347         3.0              0.133                    0.2050           180.0
# 6348         4.0              0.133                    0.5200           190.0
# 6349         3.0              0.133                    0.2050           180.0
# 6350         4.0              0.133                    0.5200           190.0
#
#       min:vdw_radius_alvarez  min:vdw_radius_mm3  min:vdw_radius_uff  \
# 0                      146.0               171.0               284.0
# 1                      247.0               252.0               370.3
# 2                      189.0               215.0               403.5
# 3                      182.0               207.0               305.2
# 5                      204.0               234.0               296.3
# ...                      ...                 ...                 ...
# 5976                   199.0               223.0               291.2
# 6347                   189.0               215.0               275.4
# 6348                   182.0               229.0               275.4
# 6349                   189.0               215.0               275.4
# 6350                   182.0               229.0               275.4
#
#       min:sound_velocity  min:Polarizability
# 0            2826.915883               0.557
# 1            1620.000000               6.600
# 2             818.000000               2.900
# 3             206.000000               2.180
# 5            3289.214936               5.350
# ...                  ...                 ...
# 5976         2610.000000               5.500
# 6347         2680.000000               2.900
# 6348         2680.000000               3.770
# 6349         2680.000000               2.900
# 6350         2680.000000               3.770
#
# [4527 rows x 294 columns]

# %%
random.seed(1234)
np.random.seed(1234)
data_train, data_test = sklearn.model_selection.train_test_split(data, test_size=0.2)
mean, std = data_train.mean(), data_train.std()

data_train_scaled = (data_train - mean) / std
data_test_scaled = (data_test - mean) / std

# %%
model = tpot.TPOTRegressor(
    generations=None,
    population_size=100,
    max_eval_time_mins=1/60,
    max_time_mins=10,
    cv=10,
    verbosity=2,
    scoring="neg_root_mean_squared_error",
    config_dict=tpot.config.regressor_config_dict,
    n_jobs=-1,
    random_state=1234
)

# %%
#newmod = model
newmod
# Out:
# TPOTRegressor(config_dict={'sklearn.cluster.FeatureAgglomeration': {'affinity': ['euclidean',
#                                                                                  'l1',
#                                                                                  'l2',
#                                                                                  'manhattan',
#                                                                                  'cosine'],
#                                                                     'linkage': ['ward',
#                                                                                 'complete',
#                                                                                 'average']},
#                            'sklearn.decomposition.FastICA': {'tol': array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])},
#                            'sklearn.decomposition.PCA': {'iterated_power'...
#                                                     'n_estimators': [100],
#                                                     'n_jobs': [1],
#                                                     'objective': ['reg:squarederror'],
#                                                     'subsample': array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#                                                     'verbosity': [0]}},
#               cv=10, generations=1000000,
#               max_eval_time_mins=0.016666666666666666, max_time_mins=10,
#               n_jobs=-1, random_state=1234,
#               scoring='neg_root_mean_squared_error', verbosity=2)

# %%
model = sklearn.ensemble.GradientBoostingRegressor(n_estimators=200, max_depth=5)

# %%
target = "bandgap (eV)"
train_x = np.nan_to_num(data_train_scaled.drop(columns=[target]).to_numpy())
train_y = np.nan_to_num(data_train_scaled[target].to_numpy().ravel())

test_x = np.nan_to_num(data_test_scaled.drop(columns=[target]).to_numpy())
test_y = np.nan_to_num(data_test_scaled[target].to_numpy().ravel())

model.fit(train_x, train_y)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=200)

# %%
def unscale(arr):
    return arr * std[target] + mean[target]
    
train_pred_y = model.predict(train_x)
test_pred_y = model.predict(test_x[:340,:])

# %%
models = {}

models["r1_1term"] = lambda df: -7.517588190691672e-03 + 3.019120658205411e-01 * (df["ave:fusion_enthalpy"] - df["ave:electron_affinity"])
models["r1_2term"] = lambda df: -4.220354429619663e-01 + 3.043650335588696e-01 * np.exp(df["sum:gs_energy"]) + \
                                 3.290126411913264e-01 * (df["ave:fusion_enthalpy"] - df["ave:electron_affinity"])
models["r2_1term"] = lambda df: -4.730850253495772e-01 + 3.491171896552910e-01 * (np.exp(df["sum:gs_energy"]) + (df["ave:fusion_enthalpy"] - df["ave:electron_affinity"]))

data_train_scaled_sisso = data_train_scaled.copy()
data_test_scaled_sisso = data_test_scaled.copy()
for key,fun in models.items():
    data_train_scaled_sisso[key] = fun(data_train_scaled_sisso)
    data_test_scaled_sisso[key] = fun(data_test_scaled_sisso)

data_train_scaled_sisso.head()
# Out:
#       exfoliation_energy_per_atom (eV/atom)  energy_vdw_per_atom (eV/atom)  \
# 1516                              -0.479635                      -0.311201
# 47                                -0.425963                       0.764286
# 1783                              -0.314773                       0.031836
# 4429                               0.091167                      -1.074093
# 4878                              -0.143386                       0.115064
#
#       total_magnetization (Bohr Magneton)  bandgap (eV)  ave:atomic_number  \
# 1516                             2.957530     -0.282886          -0.838933
# 47                              -0.353991      0.682514          -0.620620
# 1783                             2.294953     -0.554272           0.097699
# 4429                             0.968450      1.596636          -1.162241
# 4878                             1.301939      2.090177          -1.047387
#
#       ave:atomic_radius  ave:atomic_radius_rahm  ave:atomic_volume  \
# 1516          -0.674579               -1.656669          -0.266261
# 47            -1.091742               -0.253270          -0.543328
# 1783           0.193261                0.263771           0.436272
# 4429          -0.196250               -1.179916          -0.586454
# 4878          -0.656519               -1.789622          -0.088560
#
#       ave:atomic_weight  ave:boiling_point  ...  min:thermal_conductivity  \
# 1516          -0.821420          -0.284481  ...                 -0.304808
# 47            -0.600563           0.844793  ...                 -0.300745
# 1783           0.031331          -0.293837  ...                 -0.300745
# 4429          -1.151220          -1.088354  ...                 -0.304858
# 4878          -1.013731          -1.359636  ...                 -0.304808
#
#       min:vdw_radius  min:vdw_radius_alvarez  min:vdw_radius_mm3  \
# 1516       -0.991026               -1.025982           -1.344255
# 47          0.579815                0.269250            0.317746
# 1783        0.579815                0.269250            0.582155
# 4429       -0.784336               -0.896459           -0.928755
# 4878       -0.991026               -1.025982           -1.344255
#
#       min:vdw_radius_uff  min:sound_velocity  min:Polarizability  r1_1term  \
# 1516           -0.641580            0.716255           -0.840521 -0.539790
# 47              1.527564            0.475414            0.045432  0.315668
# 1783           -0.591600            0.475414            0.052597 -0.353465
# 4429           -0.969450           -0.965801           -0.752750 -0.057017
# 4878           -0.715551            0.716255           -0.840521 -0.708034
#
#       r1_2term  r2_1term
# 1516 -0.842870 -0.905954
# 47    0.318161  0.345682
# 1783 -0.318780 -0.322252
# 4429 -0.419143 -0.465132
# 4878 -0.853709 -0.902632
#
# [5 rows x 297 columns]

# %%
tpot_mae =  np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(train_y), y_pred=unscale(train_pred_y)),2)
r1_1t_mae = np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(train_y), y_pred=unscale(data_train_scaled_sisso["r1_1term"])),2)
r1_2t_mae = np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(train_y), y_pred=unscale(data_train_scaled_sisso["r1_2term"])),2)
r2_1t_mae = np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(train_y), y_pred=unscale(data_train_scaled_sisso["r2_1term"])),2)

plt.rcParams["figure.dpi"]=200
fig, (ax1, ax2, ax3) = plt.subplots(1,3, sharex=True, sharey=True)
ax1.set_ylabel("Actual DFT Decomposition Energy (eV)")
ax2.set_xlabel("Predicted DFT Decomposition Energy (eV)")


    
ax1.scatter(x=unscale(data_train_scaled_sisso["r1_1term"]), y=unscale(train_y), marker="v", color="red",alpha=0.2, label=f"Rung 1, 1-Term, MAE={r1_1t_mae}")
ax2.scatter(x=unscale(data_train_scaled_sisso["r1_2term"]), y=unscale(train_y), marker="^", color="green", alpha=0.2, label=f"Rung 1, 2-Term, MAE={r1_2t_mae}")
ax3.scatter(x=unscale(data_train_scaled_sisso["r2_1term"]), y=unscale(train_y), marker="s", color="blue", alpha=0.2, label=f"Rung 2, 1-term, MAE={r2_1t_mae}")
for ax in (ax1, ax2, ax3):
    ax.scatter(x=unscale(train_pred_y), y=unscale(train_y), color="black", alpha=0.3, marker="+", label=f"TPOT, 108 Terms, MAE={tpot_mae}")
    ax.plot([0, 3], [0, 3], color="black", linestyle="--", label="Parity")
    
for ax in (ax1, ax2, ax3):
    ax.legend(prop={"size":5}, loc="upper center")

ax2.set_title("Training Set (80% of Dataset)")
plt.show()

# %%
tpot_mae =  np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(test_y[:340]), y_pred=unscale(test_pred_y)),2)
r1_1t_mae = np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(test_y), y_pred=unscale(data_test_scaled_sisso["r1_1term"])),2)
r1_2t_mae = np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(test_y), y_pred=unscale(data_test_scaled_sisso["r1_2term"])),2)
r2_1t_mae = np.round(sklearn.metrics.mean_absolute_error(y_true=unscale(test_y), y_pred=unscale(data_test_scaled_sisso["r2_1term"])),2)

plt.rcParams["figure.dpi"]=200
fig, (ax1, ax2, ax3) = plt.subplots(1,3, sharex=True, sharey=True)
ax1.set_ylabel("DFT Decomposition Energy (eV/Atom)")
ax2.set_xlabel("Predicted Decomposition Energy (eV/Atom)")
 
ax1.scatter(x=unscale(data_test_scaled_sisso["r1_1term"]), y=unscale(test_y), marker="v", color="red",alpha=0.2, label=f"Rung 1, 1-Term, MAE={r1_1t_mae}")
ax2.scatter(x=unscale(data_test_scaled_sisso["r1_2term"]), y=unscale(test_y), marker="^", color="green", alpha=0.2, label=f"Rung 1, 2-Term, MAE={r1_2t_mae}")
ax3.scatter(x=unscale(data_test_scaled_sisso["r2_1term"]), y=unscale(test_y), marker="s", color="blue", alpha=0.2, label=f"Rung 2, 1-term, MAE={r2_1t_mae}")
for ax in (ax1, ax2, ax3):
    ax.scatter(x=unscale(test_pred_y[:340]), y=unscale(test_y[:340]), color="black", alpha=0.3, marker="+", label=f"TPOT, 108 Terms, MAE={tpot_mae}")
    ax.plot([0, 3], [0, 3], color="black", linestyle="--", label="Parity")

ax2.set_title("Testing Set (20% Holdout)")
for ax in (ax1, ax2, ax3):
    ax.legend(prop={"size":5}, loc="upper center")

plt.show()

# %%
imps = list(zip(model.feature_importances_, data_train_scaled.drop(columns=[target]).columns))
sorted(imps, key=lambda i: -i[0])
# Out:
# [(0.22912415015475804, 'total_magnetization (Bohr Magneton)'),
#  (0.09963689813528821, 'ave:boiling_point'),
#  (0.03622024963541163, 'max:en_pauling'),
#  (0.03253497683276793, 'var:en_pauling'),
#  (0.028665860076960592, 'var:electron_negativity'),
#  (0.026005535770520068, 'max:heat_capacity_molar'),
#  (0.024690230629371538, 'ave:first_ion_en'),
#  (0.020239624596536384, 'energy_vdw_per_atom (eV/atom)'),
#  (0.01677269604206667, 'ave:num_unfilled'),
#  (0.016468420326932152, 'ave:mendeleev_number'),
#  (0.015933222574635253, 'exfoliation_energy_per_atom (eV/atom)'),
#  (0.015423331951526446, 'ave:en_ghosh'),
#  (0.015288635890658936, 'ave:en_allen'),
#  (0.01374474424456179, 'ave:density'),
#  (0.012991127657161325, 'var:num_d_valence'),
#  (0.01173423029186494, 'var:num_p_unfilled'),
#  (0.011232860959003927, 'ave:num_p_valence'),
#  (0.010695631933258553, 'ave:vdw_radius_alvarez'),
#  (0.009247874791220958, 'ave:gs_bandgap'),
#  (0.008884400892155865, 'var:electron_affinity'),
#  (0.008058133339044902, 'ave:evaporation_heat'),
#  (0.007598477748624754, 'min:num_valance'),
#  (0.007105737606985911, 'sum:gs_bandgap'),
#  (0.006632617336069313, 'ave:electron_negativity'),
#  (0.006330155403957288, 'max:heat_of_formation'),
#  (0.006204502235726197, 'var:density'),
#  (0.0061385763749173365, 'var:num_valance'),
#  (0.006094136852342866, 'max:heat_capacity_mass'),
#  (0.005986271792131071, 'sum:num_p_valence'),
#  (0.005760653133557768, 'ave:bulk_modulus'),
#  (0.005743269794586209, 'ave:sound_velocity'),
#  (0.005669621438031664, 'ave:period'),
#  (0.00507877195425047, 'ave:heat_of_formation'),
#  (0.005005389720270608, 'var:hhi_p'),
#  (0.004974421537247445, 'var:mendeleev_number'),
#  (0.004670553083853176, 'ave:specific_heat'),
#  (0.004601099600869401, 'sum:density'),
#  (0.004565223518426137, 'var:sound_velocity'),
#  (0.004461548143949747, 'var:num_p_valence'),
#  (0.003973145178595073, 'min:gs_energy'),
#  (0.0038678050691094644, 'min:vdw_radius_uff'),
#  (0.0038432379571879667, 'ave:gs_energy'),
#  (0.003756213276051682, 'max:mendeleev_number'),
#  (0.003737870016020885, 'max:lattice_constant'),
#  (0.0035781421083889865, 'var:heat_capacity_molar'),
#  (0.0035163725663446225, 'sum:num_d_unfilled'),
#  (0.0034814392730941604, 'sum:sound_velocity'),
#  (0.00335368576920378, 'min:sound_velocity'),
#  (0.0033012478010539183, 'ave:num_d_valence'),
#  (0.0032626001631008337, 'var:thermal_conductivity'),
#  (0.0032227042410925316, 'var:num_unfilled'),
#  (0.0032009722250285625, 'ave:vdw_radius_mm3'),
#  (0.0031920864396813055, 'var:vdw_radius_mm3'),
#  (0.0031072965228474123, 'ave:thermal_conductivity'),
#  (0.0030997976436520774, 'var:en_ghosh'),
#  (0.003010320223739987, 'ave:en_pauling'),
#  (0.003005557566460707, 'var:vdw_radius_uff'),
#  (0.0029350083771153613, 'ave:lattice_constant'),
#  (0.0029028107679377113, 'sum:electron_affinity'),
#  (0.0028972114784298736, 'ave:covalent_radius_cordero'),
#  (0.0028052217934958334, 'ave:icsd_volume'),
#  (0.002708979803974481, 'var:first_ion_en'),
#  (0.0026981764625553595, 'min:heat_capacity_molar'),
#  (0.002545028221673848, 'sum:thermal_conductivity'),
#  (0.0025325413860205837, 'min:lattice_constant'),
#  (0.0025037316006475178, 'min:first_ion_en'),
#  (0.0024950533546749688, 'sum:bulk_modulus'),
#  (0.0023777245434520792, 'var:gs_energy'),
#  (0.0023561472081973095, 'min:molar_volume'),
#  (0.0023120566763109914, 'sum:fusion_enthalpy'),
#  (0.002285204274877142, 'var:atomic_volume'),
#  (0.0022412332621212475, 'sum:heat_capacity_molar'),
#  (0.0022094098907217046, 'max:num_d_unfilled'),
#  (0.0022004480128695065, 'max:fusion_enthalpy'),
#  (0.0021528158771497823, 'sum:heat_of_formation'),
#  (0.002145564973410751, 'var:hhi_r'),
#  (0.002065522895017839, 'sum:gs_energy'),
#  (0.002058847437396944, 'ave:melting_point'),
#  (0.0019160328410291077, 'ave:atomic_number'),
#  (0.0018867172171152108, 'var:num_d_unfilled'),
#  (0.0018730147916426135, 'max:density'),
#  (0.001863786473710796, 'ave:atomic_weight'),
#  (0.0018586471703801299, 'ave:hhi_r'),
#  (0.0018572401158632843, 'max:thermal_conductivity'),
#  (0.0018217882514334712, 'ave:vdw_radius_uff'),
#  (0.0017087416645205804, 'var:gs_est_bcc_latcnt'),
#  (0.0017006329481341852, 'var:molar_volume'),
#  (0.0016157341108233758, 'var:fusion_enthalpy'),
#  (0.0016149879880872603, 'var:icsd_volume'),
#  (0.001598551269715911, 'var:en_allen'),
#  (0.0015836156785973545, 'sum:mendeleev_number'),
#  (0.0015786740649336105, 'min:covalent_radius_pyykko_triple'),
#  (0.001561532177073247, 'ave:gs_mag_moment'),
#  (0.0015237695016748112, 'min:atomic_volume'),
#  (0.001520174186834136, 'sum:heat_capacity_mass'),
#  (0.0015184094946823618, 'var:atomic_radius_rahm'),
#  (0.0015054949018176232, 'ave:vdw_radius'),
#  (0.0015022882951817962, 'ave:heat_capacity_molar'),
#  (0.0015021050570112892, 'sum:specific_heat'),
#  (0.0014860610246760777, 'ave:fusion_enthalpy'),
#  (0.001483187654524835, 'sum:hhi_r'),
#  (0.0014781595671124147, 'sum:electron_negativity'),
#  (0.0014781210075576997, 'min:atomic_weight'),
#  (0.001379073889252554, 'ave:covalent_radius_pyykko_triple'),
#  (0.0013581609701143274, 'sum:Polarizability'),
#  (0.0013399230936923033, 'ave:hhi_p'),
#  (0.0013166298552599034, 'sum:evaporation_heat'),
#  (0.001299740886507301, 'sum:num_unfilled'),
#  (0.0012984949230828223, 'var:covalent_radius_cordero'),
#  (0.0012906031960399334, 'sum:atomic_volume'),
#  (0.001289874610080954, 'min:melting_point'),
#  (0.001272757954457727, 'var:vdw_radius_alvarez'),
#  (0.0012382125564651522, 'max:gs_mag_moment'),
#  (0.0012345963172413908, 'var:gs_bandgap'),
#  (0.0012075719971143667, 'var:covalent_radius_pyykko_triple'),
#  (0.0011970957444455224, 'sum:atomic_weight'),
#  (0.001189552997946972, 'sum:vdw_radius_uff'),
#  (0.0011575007065310835, 'var:bulk_modulus'),
#  (0.0011276604757661805, 'var:heat_capacity_mass'),
#  (0.001105856942468016, 'var:lattice_constant'),
#  (0.0010790170463352124, 'ave:atomic_radius_rahm'),
#  (0.001078952216638766, 'ave:electron_affinity'),
#  (0.0010648067037678781, 'sum:dipole_polarizability'),
#  (0.0010633452971649895, 'sum:en_pauling'),
#  (0.0010442399292817548, 'sum:gs_volume_per'),
#  (0.0010429350320268263, 'max:sound_velocity'),
#  (0.0010097899914252937, 'var:covalent_radius_pyykko_double'),
#  (0.0009997851976709206, 'var:covalent_radius_slater'),
#  (0.0009597945636947658, 'sum:gs_est_bcc_latcnt'),
#  (0.0009556643576115959, 'sum:lattice_constant'),
#  (0.0009542570621851013, 'sum:covalent_radius_pyykko_triple'),
#  (0.0009182037286734298, 'sum:boiling_point'),
#  (0.0008833543783656203, 'var:heat_of_formation'),
#  (0.0008765339659335468, 'min:bulk_modulus'),
#  (0.0008663223571402263, 'min:heat_of_formation'),
#  (0.0008588792375148344, 'var:evaporation_heat'),
#  (0.0008402379595964043, 'ave:gs_volume_per'),
#  (0.0008252040940919105, 'sum:num_p_unfilled'),
#  (0.0008233101822256074, 'ave:gs_est_bcc_latcnt'),
#  (0.0008102589244545681, 'min:gs_volume_per'),
#  (0.0008045311130341417, 'ave:dipole_polarizability'),
#  (0.0008043814507771734, 'var:melting_point'),
#  (0.0008033881218833676, 'var:vdw_radius'),
#  (0.000796780729904918, 'sum:num_s_unfilled'),
#  (0.0007616973723937574, 'sum:melting_point'),
#  (0.0007578343806478673, 'max:vdw_radius'),
#  (0.0007429975840765998, 'ave:covalent_radius_pyykko_double'),
#  (0.0007235210483660367, 'max:gs_energy'),
#  (0.0007231872283412211, 'ave:num_d_unfilled'),
#  (0.0007085425413109888, 'min:gs_est_bcc_latcnt'),
#  (0.0006930221216782663, 'min:en_allen'),
#  (0.0006926446507448037, 'sum:gs_mag_moment'),
#  (0.0006903786814742937, 'max:vdw_radius_uff'),
#  (0.0006709123278449906, 'sum:first_ion_en'),
#  (0.0006690095744075371, 'var:atomic_weight'),
#  (0.0006684261627229978, 'ave:gs_est_fcc_latcnt'),
#  (0.0006498088127421951, 'ave:covalent_radius_slater'),
#  (0.00063795140443454, 'ave:num_s_unfilled'),
#  (0.0006304799117613186, 'sum:en_ghosh'),
#  (0.0006297451661298708, 'sum:num_valance'),
#  (0.0006227572078748925, 'sum:atomic_number'),
#  (0.0006197699269175233, 'min:electron_affinity'),
#  (0.0006113183051016508, 'ave:num_valance'),
#  (0.0006045075913891242, 'max:covalent_radius_pyykko_triple'),
#  (0.0005945821371568281, 'max:bulk_modulus'),
#  (0.0005930423691309836, 'var:atomic_radius'),
#  (0.0005871299714983752, 'sum:c6_gb'),
#  (0.0005753175788491958, 'var:dipole_polarizability'),
#  (0.0005619188420509781, 'min:heat_capacity_mass'),
#  (0.0005596813590278382, 'sum:num_s_valence'),
#  (0.0005522220313345237, 'max:c6_gb'),
#  (0.0005513002706202275, 'var:gs_volume_per'),
#  (0.0005482514547866599, 'min:specific_heat'),
#  (0.00054719649276108, 'sum:en_allen'),
#  (0.0005423013793044217, 'var:covalent_radius_pyykko'),
#  (0.0005229533494480259, 'max:boiling_point'),
#  (0.0005210224918358871, 'max:covalent_radius_cordero'),
#  (0.0005198803319279816, 'var:boiling_point'),
#  (0.0005015488637088435, 'ave:atomic_radius'),
#  (0.0004968132558325159, 'sum:hhi_p'),
#  (0.0004912290695528603, 'var:num_s_valence'),
#  (0.00046459571087896446, 'max:atomic_radius_rahm'),
#  (0.0004310588448977954, 'ave:molar_volume'),
#  (0.0004238711874848562, 'max:melting_point'),
#  (0.0004007965491881524, 'ave:num_p_unfilled'),
#  (0.00039884494982392636, 'sum:vdw_radius_alvarez'),
#  (0.0003959531803716905, 'sum:icsd_volume'),
#  (0.0003665943991434137, 'var:specific_heat'),
#  (0.00036397773615848397, 'var:atomic_number'),
#  (0.0003621612129686002, 'sum:num_f_valence'),
#  (0.00034530548408637614, 'max:molar_volume'),
#  (0.00034506673939986213, 'ave:num_s_valence'),
#  (0.0003440864422659749, 'var:gs_est_fcc_latcnt'),
#  (0.0003416642682497872, 'sum:molar_volume'),
#  (0.00032102191325726484, 'ave:Polarizability'),
#  (0.0003150504317382321, 'var:c6_gb'),
#  (0.0003049044838633188, 'max:num_p_unfilled'),
#  (0.00026323972525191415, 'var:Polarizability'),
#  (0.0002600928278274125, 'ave:covalent_radius_pyykko'),
#  (0.00025949811278414714, 'ave:c6_gb'),
#  (0.0002592464452630594, 'min:mendeleev_number'),
#  (0.00025815844405586584, 'max:electron_affinity'),
#  (0.0002512353432413676, 'sum:covalent_radius_pyykko'),
#  (0.00023970077391068868, 'max:atomic_volume'),
#  (0.00022637896122010403, 'sum:vdw_radius'),
#  (0.00022519876261464287, 'sum:covalent_radius_cordero'),
#  (0.00021956571774817788, 'sum:num_d_valence'),
#  (0.0002186406892898087, 'max:en_allen'),
#  (0.000208681969442357, 'min:atomic_radius'),
#  (0.00020847816898313297, 'min:hhi_r'),
#  (0.0002071879890842555, 'ave:heat_capacity_mass'),
#  (0.00019432011964963059, 'max:atomic_radius'),
#  (0.00017698514212252794, 'ave:atomic_volume'),
#  (0.0001723550194941867, 'sum:atomic_radius'),
#  (0.00016834214296119733, 'min:covalent_radius_pyykko_double'),
#  (0.0001672196174423401, 'min:gs_bandgap'),
#  (0.00015817227929103384, 'sum:covalent_radius_pyykko_double'),
#  (0.00015508170596229993, 'max:en_ghosh'),
#  (0.00015490118658204822, 'min:en_pauling'),
#  (0.000151735331685615, 'min:en_ghosh'),
#  (0.0001511921086578124, 'sum:covalent_radius_slater'),
#  (0.0001506460880208475, 'var:num_s_unfilled'),
#  (0.00014803939941496853, 'max:hhi_p'),
#  (0.00014769137858527495, 'max:electron_negativity'),
#  (0.00014461513942836077, 'var:period'),
#  (0.00013887649795920506, 'max:first_ion_en'),
#  (0.00013256567106084447, 'max:covalent_radius_pyykko_double'),
#  (0.00012494063843126487, 'var:gs_mag_moment'),
#  (0.00010665323843900331, 'min:electron_negativity'),
#  (9.823486530503082e-05, 'max:num_unfilled'),
#  (9.735116947585011e-05, 'max:gs_volume_per'),
#  (8.899701616638429e-05, 'min:num_p_unfilled'),
#  (8.762316199224621e-05, 'sum:gs_est_fcc_latcnt'),
#  (8.469012424553053e-05, 'max:vdw_radius_mm3'),
#  (8.415517775139358e-05, 'max:gs_est_bcc_latcnt'),
#  (8.218520482713054e-05, 'sum:vdw_radius_mm3'),
#  (8.097867616596931e-05, 'max:atomic_number'),
#  (7.921064119416987e-05, 'min:gs_est_fcc_latcnt'),
#  (6.11693013072227e-05, 'max:covalent_radius_slater'),
#  (5.909272318155491e-05, 'sum:period'),
#  (4.516110685586024e-05, 'sum:atomic_radius_rahm'),
#  (4.4709500309180466e-05, 'min:density'),
#  (4.468038025357773e-05, 'min:icsd_volume'),
#  (4.390321691991037e-05, 'min:covalent_radius_pyykko'),
#  (4.385741945756414e-05, 'max:dipole_polarizability'),
#  (4.076429519360778e-05, 'min:vdw_radius'),
#  (3.9383771793753546e-05, 'max:gs_bandgap'),
#  (3.8069271210912836e-05, 'ave:num_f_unfilled'),
#  (3.584465884395821e-05, 'max:Polarizability'),
#  (3.492361003512193e-05, 'min:atomic_number'),
#  (3.071427087393295e-05, 'max:specific_heat'),
#  (2.7470118101951866e-05, 'max:evaporation_heat'),
#  (2.5081896970207242e-05, 'var:num_f_unfilled'),
#  (2.2725253285854337e-05, 'min:boiling_point'),
#  (2.2486625171081916e-05, 'ave:num_f_valence'),
#  (2.1733359122646402e-05, 'max:num_valance'),
#  (2.0753323009449025e-05, 'max:atomic_weight'),
#  (1.927782750967155e-05, 'max:vdw_radius_alvarez'),
#  (1.623624392643559e-05, 'var:num_f_valence'),
#  (1.4653212981121753e-05, 'max:gs_est_fcc_latcnt'),
#  (1.0251254459400095e-05, 'max:num_d_valence'),
#  (1.0162487387294427e-05, 'max:hhi_r'),
#  (6.710424886912182e-06, 'min:dipole_polarizability'),
#  (6.507846512523501e-06, 'min:Polarizability'),
#  (5.780747520539911e-06, 'min:num_s_valence'),
#  (4.4481000426051e-06, 'min:num_p_valence'),
#  (3.722925302277065e-06, 'min:hhi_p'),
#  (2.390709248830854e-06, 'min:atomic_radius_rahm'),
#  (1.5094095301272753e-06, 'min:vdw_radius_alvarez'),
#  (1.2515032609267453e-06, 'max:num_p_valence'),
#  (1.2277988047193673e-06, 'max:icsd_volume'),
#  (8.311451755567963e-07, 'max:covalent_radius_pyykko'),
#  (6.931332565306186e-07, 'min:thermal_conductivity'),
#  (4.1191174547862467e-07, 'min:covalent_radius_slater'),
#  (2.1660157108166496e-07, 'max:period'),
#  (1.8730255862114562e-07, 'min:c6_gb'),
#  (1.22834622353782e-07, 'min:evaporation_heat'),
#  (6.128082802635812e-08, 'max:num_s_unfilled'),
#  (3.765818881323143e-08, 'min:vdw_radius_mm3'),
#  (1.953058248009997e-08, 'min:covalent_radius_cordero'),
#  (0.0, 'sum:num_f_unfilled'),
#  (0.0, 'max:num_f_unfilled'),
#  (0.0, 'max:num_f_valence'),
#  (0.0, 'max:num_s_valence'),
#  (0.0, 'min:fusion_enthalpy'),
#  (0.0, 'min:gs_mag_moment'),
#  (0.0, 'min:num_unfilled'),
#  (0.0, 'min:num_d_unfilled'),
#  (0.0, 'min:num_d_valence'),
#  (0.0, 'min:num_f_unfilled'),
#  (0.0, 'min:num_f_valence'),
#  (0.0, 'min:num_s_unfilled'),
#  (0.0, 'min:period')]
